# %% [markdown]
# # Inference VITS Model on CPU and Compilation on Neuron
# * Conditional Variational Autoencoder with Adversarial Learning for End-to-End Text-to-Speech
#     * Git: https://github.com/jaywalnut310/vits.git

# %%
import sys
import os
sys.path.append(os.path.abspath("../"))

for i in sys.path:
    print(i)
# Out:
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python310.zip
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/lib-dynload
#
# /home/ubuntu/.local/lib/python3.10/site-packages
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages
# /home/ubuntu/vits

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

# %% [markdown]
# ## LJ Speech

# %%
hps = utils.get_hparams_from_file("../configs/ljs_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model)
_ = net_g.eval()

_ = utils.load_checkpoint("../models/pretrained_ljs.pth", net_g, None)

# %%
def play_tts_cpu(stn_tst, net_g):
    with torch.no_grad():
        x_tst = stn_tst.unsqueeze(0)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
        # audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
        audio = net_g(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()    
        ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
    return audio

stn_tst = get_text("VITS is Awesome!", hps)    
audio = play_tts_cpu(stn_tst, net_g)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
stn_tst = get_text("VITS is Awesome!, How are you doing today?", hps)    
audio = play_tts_cpu(stn_tst, net_g)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Neuron Complie Test

# %%
import torch
import torch_neuron
from torch_neuron import analyze_model

# %%
# wrapping model
class VITSWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x, x_lengths, noise_scale, noise_scale_w, length_scale):
        return self.model.infer(x, x_lengths, 
                                noise_scale=noise_scale.item(),
                                noise_scale_w=noise_scale_w.item(), 
                                length_scale=length_scale.item())

wrapped_model = VITSWrapper(net_g)

# %%
stn_tst = torch.randint(low=1, high=10, size=(33,), dtype=torch.int64)
x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])

# 스칼라 값을 텐서로 변환
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

print("x_tst: ", x_tst)
print("x_tst shape: ", x_tst.shape)
print("x_tst_length shape: ", x_tst_lengths.shape)
print("x_tst_length: ", x_tst_lengths)
# Out:
# x_tst:  tensor([[4, 2, 7, 5, 1, 7, 6, 8, 9, 9, 1, 1, 6, 7, 2, 5, 2, 7, 6, 9, 6, 6, 1, 8,
#          5, 5, 3, 4, 4, 9, 3, 9, 5]])
# x_tst shape:  torch.Size([1, 33])
# x_tst_length shape:  torch.Size([1])
# x_tst_length:  tensor([33])

# %%
# torch_neuron.trace 사용
traced_model = torch_neuron.trace(wrapped_model, 
                                  (x_tst, x_tst_lengths, 
                                   noise_scale, noise_scale_w, length_scale))
# Out:
# /tmp/ipykernel_38631/1292780826.py:9: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   noise_scale=noise_scale.item(),
# /tmp/ipykernel_38631/1292780826.py:10: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   noise_scale_w=noise_scale_w.item(),
# /tmp/ipykernel_38631/1292780826.py:11: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   length_scale=length_scale.item())
# /home/ubuntu/vits/attentions.py:157: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert t_s == t_t, "Relative attention is only available for self-attention."
# /home/ubuntu/vits/attentions.py:202: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_length = max(length - (self.window_size + 1), 0)
# /home/ubuntu/vits/attentions.py:203: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   slice_start_position = max((self.window_size + 1) - length, 0)
# /home/ubuntu/vits/attentions.py:205: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_length > 0:
# /home/ubuntu/vits/transforms.py:105: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if torch.min(inputs) < left or torch.max(inputs) > right:
# /home/ubuntu/vits/transforms.py:110: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_bin_width * num_bins > 1.0:
# /home/ubuntu/vits/transforms.py:112: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_bin_height * num_bins > 1.0:
# /home/ubuntu/vits/transforms.py:164: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert (discriminant >= 0).all()
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%7608 : Float(1, 192, 65, strides=[12480, 1, 192], requires_grad=0, device=cpu) = aten::randn_like(%m_p, %7603, %7604, %7605, %7606, %7607) # /home/ubuntu/vits/models.py:539:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _check_trace(
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# The values for attribute 'shape' do not match: torch.Size([1, 1, 12288]) != torch.Size([1, 1, 13312]).
#   _check_trace(
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# The values for attribute 'shape' do not match: torch.Size([1, 1, 48, 33]) != torch.Size([1, 1, 52, 33]).
#   _check_trace(
# /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch/jit/_trace.py:1001: TracerWarning: Output nr 3. of the traced function does not match the corresponding output of the Python function. Detailed error:
# The values for attribute 'shape' do not match: torch.Size([1, 1, 48]) != torch.Size([1, 1, 52]).
#   _check_trace(
# INFO:Neuron:There are 61 ops of 7 different types in the TorchScript that are not compiled by neuron-cc: prim::CallFunction, aten::randn_like, aten::index_put_, aten::gather, aten::index, aten::randn, aten::embedding, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/compiler/neuron-cc/neuron-cc-ops/neuron-cc-ops-pytorch.html)
# [INFO] There are 61 ops of 7 different types in the TorchScript that are not compiled by neuron-cc: prim::CallFunction, aten::randn_like, aten::index_put_, aten::gather, aten::index, aten::randn, aten::embedding, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/compiler/neuron-cc/neuron-cc-ops/neuron-cc-ops-pytorch.html)
# INFO:Neuron:Number of arithmetic operators (pre-compilation) before = 2009, fused = 1958, percent fused = 97.46%
# [INFO] Number of arithmetic operators (pre-compilation) before = 2009, fused = 1958, percent fused = 97.46%
# [WARNING] From /home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/ops/aten.py:2412: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:Neuron:Compiling function _NeuronGraph$1025 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1025 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py310/bin/neuron-cc compile /tmp/tmpn_kv3ebq/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpn_kv3ebq/graph_def.neff --io-config {"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py310/bin/neuron-cc compile /tmp/tmpn_kv3ebq/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpn_kv3ebq/graph_def.neff --io-config {"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]} --verbose 35'
# ...complexity:  7250
#
# DFNLayout 0 broadcast=ax1_14_12=[0:33:1] block= par= free=ax1_14_12=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=1)
# 	l 6 1:0   [2] [F] ['0']
# 	l 17 t4  const [1, 33] [F,F] ['0', 'ax1_14_12']
# 	s 30 cast0:0   [33] [F] ['ax1_14_12']
# 	s 33 TextEncoder_8/aten_to/Cast:0   [1, 1, 33] [F,F,F] ['0', '0', 'ax1_14_12']
#
#
#
# DFNLayout 1 broadcast=i2_7=[0:192:1] block= par=i1_7=[0:33:1] free=i2_7=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 53 cast0:0   [33] [P] ['i1_7']
# 	l 41 0:0   [1, 33, 192] [F,P,F] ['0', 'i1_7', 'i2_7']
# 	s 70 TextEncoder_8/Encoder_31/aten_mul_1/mul:0   [192, 33] [F,P] ['i2_7', 'i1_7']
#
#
#
# TensorContractLayout 2 block= load_par= store_par=ax2_78_76=[0:33:1] free=ax3_79_76=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 85 cast0:0   [33] [F] ['ax2_78_76']
# 	l 74 cast0:0   [33] [F] ['ax3_79_76']
# 	r       |V2 $6833[ax2_78_76,ax3_79_76] = tensor_contract_multiply_add(|V2 $74[ax2_78_76,ax3_79_76], |V2 $85[ax2_78_76,ax3_79_76], contract={}, lhs_free={ax3_79_76=[0:33:1]}, rhs_free={ax2_78_76=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/aten_mul/mul
# 	s 103 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
# 	s 977 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
# 	s 1850 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
# 	s 2723 TextEncoder_8/Encoder_31/MultiHeadAttention_85/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
# 	s 3596 TextEncoder_8/Encoder_31/MultiHeadAttention_95/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
# 	s 4469 TextEncoder_8/Encoder_31/MultiHeadAttention_105/aten_eq/Equal:0   [33, 33] [P,F] ['ax2_78_76', 'ax3_79_76']
#
#
#
# TensorContractLayout 3 block=m_14_0=[0:2:1] load_par=c_14=[0:192:1] store_par=m_14_1=[0:96:1] free=w_14=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 136 t134  const [192] [P] ['96m_14_0+m_14_1']
# 	l 113 TextEncoder_8/Encoder_31/aten_mul_1/mul:0   [192, 33] [P,F] ['c_14', 'w_14']
# 	l 123 t121  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_14', '96m_14_0+m_14_1']
# 	r           |V2 $6377[w_14,m_14_0,m_14_1] = tensor_contract_multiply_add(|V2 $113[w_14,m_14_0,m_14_1,c_14], |V2 $123[w_14,m_14_0,m_14_1,c_14], contract={c_14=[0:192:1]}, lhs_free={w_14=[0:33:1]}, rhs_free={m_14_0=[0:2:1],m_14_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/Conv1d_7/aten__convolution/conv1d
# 	s 6472 reshape0:0   [2, 33, 96] [B,F,P] ['m_14_0', 'w_14', 'm_14_1']
# 	s 6485 reshape2:0   [2, 33, 96] [B,F,P] ['m_14_0', 'w_14', 'm_14_1']
#
#
#
# TensorContractLayout 4 block=m_24_0=[0:2:1] load_par=c_24=[0:192:1] store_par=m_24_1=[0:96:1] free=w_24=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 188 t186  const [192] [P] ['96m_24_0+m_24_1']
# 	l 165 TextEncoder_8/Encoder_31/aten_mul_1/mul:0   [192, 33] [P,F] ['c_24', 'w_24']
# 	l 175 t173  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_24', '96m_24_0+m_24_1']
# 	r           |V2 $6378[w_24,m_24_0,m_24_1] = tensor_contract_multiply_add(|V2 $165[w_24,m_24_0,m_24_1,c_24], |V2 $175[w_24,m_24_0,m_24_1,c_24], contract={c_24=[0:192:1]}, lhs_free={w_24=[0:33:1]}, rhs_free={m_24_0=[0:2:1],m_24_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/Conv1d_8/aten__convolution/conv1d
# 	s 6476 t195   [2, 96, 33] [B,P,F] ['m_24_0', 'm_24_1', 'w_24']
#
#
#
# TensorContractLayout 5 block=i0_34=[0:2:1] load_par=i3_34=[0:96:1] store_par=i2_34=[0:33:1] free=i1_34=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=3168)
# 	l 217 reshape0:0   [2, 33, 96] [B,F,P] ['i0_34', 'i1_34', 'i3_34']
# 	l 199 t195   [2, 96, 33] [B,P,F] ['i0_34', 'i3_34', 'i2_34']
# 	r           |V2 $6379[i0_34,i1_34,i2_34] = tensor_contract_multiply_add(|V2 $217[i0_34,i1_34,i2_34,i3_34], |V2 $199[i0_34,i1_34,i2_34,i3_34], contract={i3_34=[0:96:1]}, lhs_free={i1_34=[0:33:1]}, rhs_free={i2_34=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul/MatMul
# 	s 6483 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul/MatMul:0   [2, 33, 33] [B,F,P] ['i0_34', 'i1_34', 'i2_34']
#
#
#
# TensorContractLayout 6 block=i0_40=[0:2:1] load_par=i3_40=[0:96:1] store_par=i2_40=[0:65:1] free=i1_40=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=6240)
# 	l 249 reshape2:0   [2, 33, 96] [B,F,P] ['i0_40', 'i1_40', 'i3_40']
# 	l 250 t247  const [2, 65, 96] [B,F,P] ['i0_40', 'i2_40', 'i3_40']
# 	r           |V2 $6380[i0_40,i1_40,i2_40] = tensor_contract_multiply_add(|V2 $249[i0_40,i1_40,i2_40,i3_40], |V2 $250[i0_40,i1_40,i2_40,i3_40], contract={i3_40=[0:96:1]}, lhs_free={i1_40=[0:33:1]}, rhs_free={i2_40=[0:65:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul_1/MatMul
# 	s 6821 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_view_3/Reshape:0   [2, 2113] [B,F] ['i0_40', '66i1_40+i2_40-32']
#
#
#
# DFNLayout 7 broadcast=i1_45=[0:2:1] block=i2_45_0=[0:33:1] par=i2_45_1=[0:33:1] free=i1_45=[0:2:1]
# layout_profile(block_axes_tripcount=33, parallel_axes_tripcount=33)
# 	l 267 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_view_3/Reshape:0   [2, 2113] [F,P] ['i1_45', '65i2_45_0+i2_45_1']
# 	l 384 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul/MatMul:0   [2, 33, 33] [F,B,P] ['i1_45', 'i2_45_0', 'i2_45_1']
# 	l 389 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_eq/Equal:0   [33, 33] [B,P] ['i2_45_0', 'i2_45_1']
# 	l 394 t111  const [1, 2, 33, 33] [F,F,B,P] ['0', 'i1_45', 'i2_45_0', 'i2_45_1']
# 	s 415 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_masked_fill/Select:0   [2, 33, 33] [F,B,P] ['i1_45', 'i2_45_0', 'i2_45_1']
#
#
#
# DFNLayout 8 broadcast= block= par=ax1_418_416=[0:2:1] ax2_419_416=[0:33:1] free=k1_420_416=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 421 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_418_416', 'ax2_419_416', 'k1_420_416']
# 	r         |V2 $422[ax1_418_416,ax2_419_416] = reduce_maximum(|V2 $421[ax1_418_416,ax2_419_416,k1_420_416], {k1_420_416=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_softmax/Softmax
# 	s 423 t417   [2, 33] [P,P] ['ax1_418_416', 'ax2_419_416']
#
#
#
# DFNLayout 9 broadcast=k2_427_416=[0:33:1] block= par=ax1_425_416=[0:2:1] ax2_426_416=[0:33:1] free=k2_427_416=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 429 t417   [2, 33] [P,P] ['ax1_425_416', 'ax2_426_416']
# 	l 428 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_425_416', 'ax2_426_416', 'k2_427_416']
# 	r         |V2 $432[ax1_425_416,ax2_426_416] = reduce_add(|V2 $431[ax1_425_416,ax2_426_416,k2_427_416], {k2_427_416=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_softmax/Softmax
# 	s 433 t424   [2, 33] [P,P] ['ax1_425_416', 'ax2_426_416']
#
#
#
# DFNLayout 10 broadcast=ax3_437_416=[0:33:1] block= par=ax1_435_416=[0:2:1] ax2_436_416=[0:33:1] free=ax3_437_416=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 441 t424   [2, 33] [P,P] ['ax1_435_416', 'ax2_436_416']
# 	l 439 t417   [2, 33] [P,P] ['ax1_435_416', 'ax2_436_416']
# 	l 438 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_435_416', 'ax2_436_416', 'ax3_437_416']
# 	s 444 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_softmax/Softmax:0   [2, 33, 33] [P,P,F] ['ax1_435_416', 'ax2_436_416', 'ax3_437_416']
#
#
#
# TensorContractLayout 11 block= load_par=c_57=[0:192:1] store_par=m_57_0=[0:2:1] m_57_1=[0:96:1] free=w_57=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=16384)
# 	l 475 t473  const [192] [P] ['96m_57_0+m_57_1']
# 	l 452 TextEncoder_8/Encoder_31/aten_mul_1/mul:0   [192, 33] [P,F] ['c_57', 'w_57']
# 	l 462 t460  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_57', '96m_57_0+m_57_1']
# 	r           |V2 $6381[w_57,m_57_0,m_57_1] = tensor_contract_multiply_add(|V2 $452[w_57,m_57_0,m_57_1,c_57], |V2 $462[w_57,m_57_0,m_57_1,c_57], contract={c_57=[0:192:1]}, lhs_free={w_57=[0:33:1]}, rhs_free={m_57_0=[0:2:1],m_57_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/Conv1d_9/aten__convolution/conv1d
# 	s 6492 t482   [2, 96, 33] [P,P,F] ['m_57_0', 'm_57_1', 'w_57']
#
#
#
# TensorContractLayout 12 block=i0_66=[0:2:1] load_par=i3_66=[0:33:1] store_par=i2_66=[0:96:1] free=i1_66=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=3168)
# 	l 501 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_softmax/Softmax:0   [2, 33, 33] [B,F,P] ['i0_66', 'i1_66', 'i3_66']
# 	l 486 t482   [2, 96, 33] [B,F,P] ['i0_66', 'i2_66', 'i3_66']
# 	r           |V2 $6382[i0_66,i1_66,i2_66] = tensor_contract_multiply_add(|V2 $501[i0_66,i1_66,i2_66,i3_66], |V2 $486[i0_66,i1_66,i2_66,i3_66], contract={i3_66=[0:33:1]}, lhs_free={i1_66=[0:33:1]}, rhs_free={i2_66=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul_2/MatMul
# 	s 6497 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul_2/MatMul:0   [2, 33, 96] [B,F,P] ['i0_66', 'i1_66', 'i2_66']
#
#
#
# TensorContractLayout 13 block=i0_75=[0:2:1] i1_75=[0:33:1] load_par=i3_75=[0:65:1] store_par=i2_75=[0:96:1] free=
# layout_profile(block_axes_tripcount=66, parallel_axes_tripcount=6240)
# 	l 662 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul_2/MatMul:0   [2, 33, 96] [B,B,P] ['i0_75', 'i1_75', 'i2_75']
# 	l 634 TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_softmax/Softmax:0   [2, 33, 33] [B,B,P] ['i0_75', 'i1_75', 'i1_75+i3_75-32']
# 	l 652 t649  const [2, 96, 65] [B,F,P] ['i0_75', 'i2_75', 'i3_75']
# 	r           |V2 $6383[i0_75,i1_75,i2_75] = tensor_contract_multiply_add(|V2 $634[i0_75,i1_75,i2_75,i3_75], |V2 $652[i0_75,i1_75,i2_75,i3_75], contract={i3_75=[0:65:1]}, lhs_free={i1_75=[0:33:1]}, rhs_free={i2_75=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/aten_matmul_3/MatMul
# 	s 6503 t670   [2, 96, 33] [B,P,B] ['i0_75', 'i2_75', 'i1_75']
#
#
#
# TensorContractLayout 14 block=c_83_0=[0:2:1] load_par=c_83_1=[0:96:1] store_par=m_83=[0:192:1] free=w_83=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 700 t698  const [192] [P] ['m_83']
# 	l 707 TextEncoder_8/Encoder_31/aten_mul_1/mul:0   [192, 33] [P,F] ['m_83', 'w_83']
# 	l 674 t670   [2, 96, 33] [B,P,F] ['c_83_0', 'c_83_1', 'w_83']
# 	l 687 t685  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', '96c_83_0+c_83_1', 'm_83']
# 	r           |V2 $6384[w_83,m_83] = tensor_contract_multiply_add(|V2 $674[w_83,m_83,c_83_0,c_83_1], |V2 $687[w_83,m_83,c_83_0,c_83_1], contract={c_83_0=[0:2:1],c_83_1=[0:96:1]}, lhs_free={w_83=[0:33:1]}, rhs_free={m_83=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_55/Conv1d_305/aten__convolution/conv1d
# 	s 6508 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose/transpose:0   [33, 192] [F,P] ['w_83', 'm_83']
#
#
#
# DFNLayout 15 broadcast= block= par=i1_88=[0:33:1] free=i2_88=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 716 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_88', 'i2_88']
# 	r       |V2 $717[i1_88] = reduce_add(|V2 $716[i1_88,i2_88], {i2_88=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/moments/mean
# 	s 722 TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/moments/mean:0   [33] [P] ['i1_88']
#
#
#
# DFNLayout 16 broadcast=i2_91=[0:192:1] block= par=i1_91=[0:33:1] free=i2_91=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 724 TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/moments/mean:0   [33] [P] ['i1_91']
# 	l 726 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_91', 'i2_91']
# 	s 730 subtract0:0   [33, 192] [P,F] ['i1_91', 'i2_91']
#
#
#
# DFNLayout 17 broadcast= block= par=i1_93=[0:33:1] free=i2_93=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 731 subtract0:0   [33, 192] [P,F] ['i1_93', 'i2_93']
# 	r       |V2 $738[i1_93] = reduce_add(|V2 $734[i1_93,i2_93], {i2_93=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/moments/variance
# 	s 759 TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/batchnorm/Rsqrt:0   [33] [P] ['i1_93']
#
#
#
# DFNLayout 18 broadcast=i2_97_6867=[0:192:1] block= par=i1_97_6867=[0:33:1] free=i2_97_6867=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 772 TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/moments/mean:0   [33] [P] ['i1_97_6867']
# 	s 6865 t6864   [33, 192] [P,F] ['i1_97_6867', 'i2_97_6867']
#
#
#
# DFNLayout 19 broadcast=i2_97_6871=[0:192:1] block= par=i1_97_6871=[0:33:1] free=i2_97_6871=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 794 cast0:0   [33] [P] ['i1_97_6871']
# 	s 6869 t6868   [33, 192] [P,F] ['i1_97_6871', 'i2_97_6871']
#
#
#
# TensorContractLayout 20 block= load_par= store_par=i2_97=[0:192:1] free=i1_97=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=128)
# 	l 6870 t6868   [33, 192] [F,P] ['i1_97', 'i2_97']
# 	l 6866 t6864   [33, 192] [F,P] ['i1_97', 'i2_97']
# 	l 761 TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/batchnorm/Rsqrt:0   [33] [F] ['i1_97']
# 	l 762 t760  const [192] [F] ['i2_97']
# 	r       |V2 $6385[i1_97,i2_97] = tensor_contract_multiply_add(|V2 $761[i1_97,i2_97], |V2 $762[i1_97,i2_97], contract={}, lhs_free={i1_97=[0:33:1]}, rhs_free={i2_97=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_59/aten_layer_norm/batchnorm/mul
# 	l 766 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose/transpose:0   [33, 192] [F,P] ['i1_97', 'i2_97']
# 	l 777 t771  const [192] [P] ['i2_97']
# 	s 6509 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose_1/transpose:0   [192, 33] [P,F] ['i2_97', 'i1_97']
# 	s 800 TextEncoder_8/Encoder_31/FFN_60/aten_mul/mul:0   [192, 33] [P,F] ['i2_97', 'i1_97']
#
#
#
# TensorContractLayout 21 block=s_105=[0:3:1] load_par=c_105=[0:192:1] store_par=m_105=[0:768:1] free=w_105=[0:33:1]
# layout_profile(block_axes_tripcount=36, parallel_axes_tripcount=16384)
# 	l 840 cast0:0   [33] [F] ['w_105']
# 	l 825 t823  const [768] [P] ['m_105']
# 	l 811 TextEncoder_8/Encoder_31/FFN_60/aten_mul/mul:0   [192, 33] [P,F] ['c_105', 'w_105+s_105-1']
# 	l 812 t810  const [1, 3, 192, 768] [F,B,P,F] ['0', 's_105', 'c_105', 'm_105']
# 	r           |V2 $6386[w_105,m_105] = tensor_contract_multiply_add(|V2 $811[w_105,m_105,c_105,s_105], |V2 $812[w_105,m_105,c_105,s_105], contract={c_105=[0:192:1],s_105=[0:3:1]}, lhs_free={w_105=[0:33:1]}, rhs_free={m_105=[0:768:1]}) # dl = TextEncoder_8/Encoder_31/FFN_60/Conv1d_14/aten__convolution/conv1d
# 	s 846 TextEncoder_8/Encoder_31/FFN_60/aten_mul_1/mul:0   [768, 33] [P,F] ['m_105', 'w_105']
#
#
#
# TensorContractLayout 22 block=s_111=[0:3:1] load_par=c_111=[0:768:1] store_par=m_111=[0:192:1] free=w_111=[0:33:1]
# layout_profile(block_axes_tripcount=36, parallel_axes_tripcount=16384)
# 	l 882 cast0:0   [33] [F] ['w_111']
# 	l 871 t869  const [192] [P] ['m_111']
# 	l 889 TextEncoder_8/Encoder_31/LayerNorm_59/aten_transpose_1/transpose:0   [192, 33] [P,F] ['m_111', 'w_111']
# 	l 857 TextEncoder_8/Encoder_31/FFN_60/aten_mul_1/mul:0   [768, 33] [P,F] ['c_111', 'w_111+s_111-1']
# 	l 858 t856  const [1, 3, 768, 192] [F,B,P,F] ['0', 's_111', 'c_111', 'm_111']
# 	r           |V2 $6387[w_111,m_111] = tensor_contract_multiply_add(|V2 $857[w_111,m_111,c_111,s_111], |V2 $858[w_111,m_111,c_111,s_111], contract={c_111=[0:768:1],s_111=[0:3:1]}, lhs_free={w_111=[0:33:1]}, rhs_free={m_111=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/FFN_60/Conv1d_28/aten__convolution/conv1d
# 	s 6516 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose/transpose:0   [33, 192] [F,P] ['w_111', 'm_111']
#
#
#
# DFNLayout 23 broadcast= block= par=i1_117=[0:33:1] free=i2_117=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 898 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_117', 'i2_117']
# 	r       |V2 $899[i1_117] = reduce_add(|V2 $898[i1_117,i2_117], {i2_117=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/moments/mean
# 	s 904 TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/moments/mean:0   [33] [P] ['i1_117']
#
#
#
# DFNLayout 24 broadcast=i2_120=[0:192:1] block= par=i1_120=[0:33:1] free=i2_120=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 906 TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/moments/mean:0   [33] [P] ['i1_120']
# 	l 908 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_120', 'i2_120']
# 	s 912 subtract1:0   [33, 192] [P,F] ['i1_120', 'i2_120']
#
#
#
# DFNLayout 25 broadcast= block= par=i1_122=[0:33:1] free=i2_122=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 913 subtract1:0   [33, 192] [P,F] ['i1_122', 'i2_122']
# 	r       |V2 $920[i1_122] = reduce_add(|V2 $916[i1_122,i2_122], {i2_122=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/moments/variance
# 	s 941 TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/batchnorm/Rsqrt:0   [33] [P] ['i1_122']
#
#
#
# DFNLayout 26 broadcast=i2_126_6875=[0:192:1] block= par=i1_126_6875=[0:33:1] free=i2_126_6875=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 954 TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/moments/mean:0   [33] [P] ['i1_126_6875']
# 	s 6873 t6872   [33, 192] [P,F] ['i1_126_6875', 'i2_126_6875']
#
#
#
# TensorContractLayout 27 block= load_par= store_par=i2_126=[0:192:1] free=i1_126=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=128)
# 	l 6874 t6872   [33, 192] [F,P] ['i1_126', 'i2_126']
# 	l 943 TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/batchnorm/Rsqrt:0   [33] [F] ['i1_126']
# 	l 944 t942  const [192] [F] ['i2_126']
# 	r       |V2 $6388[i1_126,i2_126] = tensor_contract_multiply_add(|V2 $943[i1_126,i2_126], |V2 $944[i1_126,i2_126], contract={}, lhs_free={i1_126=[0:33:1]}, rhs_free={i2_126=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_64/aten_layer_norm/batchnorm/mul
# 	l 948 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose/transpose:0   [33, 192] [F,P] ['i1_126', 'i2_126']
# 	l 959 t953  const [192] [P] ['i2_126']
# 	s 6517 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose_1/transpose:0   [192, 33] [P,F] ['i2_126', 'i1_126']
#
#
#
# TensorContractLayout 28 block=m_134_0=[0:2:1] load_par=c_134=[0:192:1] store_par=m_134_1=[0:96:1] free=w_134=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 1009 t1007  const [192] [P] ['96m_134_0+m_134_1']
# 	l 986 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose_1/transpose:0   [192, 33] [P,F] ['c_134', 'w_134']
# 	l 996 t994  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_134', '96m_134_0+m_134_1']
# 	r           |V2 $6389[w_134,m_134_0,m_134_1] = tensor_contract_multiply_add(|V2 $986[w_134,m_134_0,m_134_1,c_134], |V2 $996[w_134,m_134_0,m_134_1,c_134], contract={c_134=[0:192:1]}, lhs_free={w_134=[0:33:1]}, rhs_free={m_134_0=[0:2:1],m_134_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/Conv1d_7/aten__convolution/conv1d
# 	s 6524 reshape8:0   [2, 33, 96] [B,F,P] ['m_134_0', 'w_134', 'm_134_1']
# 	s 6537 reshape10:0   [2, 33, 96] [B,F,P] ['m_134_0', 'w_134', 'm_134_1']
#
#
#
# TensorContractLayout 29 block=m_144_0=[0:2:1] load_par=c_144=[0:192:1] store_par=m_144_1=[0:96:1] free=w_144=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 1061 t1059  const [192] [P] ['96m_144_0+m_144_1']
# 	l 1038 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose_1/transpose:0   [192, 33] [P,F] ['c_144', 'w_144']
# 	l 1048 t1046  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_144', '96m_144_0+m_144_1']
# 	r           |V2 $6390[w_144,m_144_0,m_144_1] = tensor_contract_multiply_add(|V2 $1038[w_144,m_144_0,m_144_1,c_144], |V2 $1048[w_144,m_144_0,m_144_1,c_144], contract={c_144=[0:192:1]}, lhs_free={w_144=[0:33:1]}, rhs_free={m_144_0=[0:2:1],m_144_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/Conv1d_8/aten__convolution/conv1d
# 	s 6528 t1068   [2, 96, 33] [B,P,F] ['m_144_0', 'm_144_1', 'w_144']
#
#
#
# TensorContractLayout 30 block=i0_154=[0:2:1] load_par=i3_154=[0:96:1] store_par=i2_154=[0:33:1] free=i1_154=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=3168)
# 	l 1090 reshape8:0   [2, 33, 96] [B,F,P] ['i0_154', 'i1_154', 'i3_154']
# 	l 1072 t1068   [2, 96, 33] [B,P,F] ['i0_154', 'i3_154', 'i2_154']
# 	r           |V2 $6391[i0_154,i1_154,i2_154] = tensor_contract_multiply_add(|V2 $1090[i0_154,i1_154,i2_154,i3_154], |V2 $1072[i0_154,i1_154,i2_154,i3_154], contract={i3_154=[0:96:1]}, lhs_free={i1_154=[0:33:1]}, rhs_free={i2_154=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul/MatMul
# 	s 6535 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul/MatMul:0   [2, 33, 33] [B,F,P] ['i0_154', 'i1_154', 'i2_154']
#
#
#
# TensorContractLayout 31 block=i0_160=[0:2:1] load_par=i3_160=[0:96:1] store_par=i2_160=[0:65:1] free=i1_160=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=6240)
# 	l 1122 reshape10:0   [2, 33, 96] [B,F,P] ['i0_160', 'i1_160', 'i3_160']
# 	l 1123 t1120  const [2, 65, 96] [B,F,P] ['i0_160', 'i2_160', 'i3_160']
# 	r           |V2 $6392[i0_160,i1_160,i2_160] = tensor_contract_multiply_add(|V2 $1122[i0_160,i1_160,i2_160,i3_160], |V2 $1123[i0_160,i1_160,i2_160,i3_160], contract={i3_160=[0:96:1]}, lhs_free={i1_160=[0:33:1]}, rhs_free={i2_160=[0:65:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul_1/MatMul
# 	s 6823 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_view_3/Reshape:0   [2, 2113] [B,F] ['i0_160', '66i1_160+i2_160-32']
#
#
#
# DFNLayout 32 broadcast=i1_165=[0:2:1] block=i2_165_0=[0:33:1] par=i2_165_1=[0:33:1] free=i1_165=[0:2:1]
# layout_profile(block_axes_tripcount=33, parallel_axes_tripcount=33)
# 	l 1140 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_view_3/Reshape:0   [2, 2113] [F,P] ['i1_165', '65i2_165_0+i2_165_1']
# 	l 1257 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul/MatMul:0   [2, 33, 33] [F,B,P] ['i1_165', 'i2_165_0', 'i2_165_1']
# 	l 1262 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_eq/Equal:0   [33, 33] [B,P] ['i2_165_0', 'i2_165_1']
# 	l 1267 t111  const [1, 2, 33, 33] [F,F,B,P] ['0', 'i1_165', 'i2_165_0', 'i2_165_1']
# 	s 1288 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_masked_fill/Select:0   [2, 33, 33] [F,B,P] ['i1_165', 'i2_165_0', 'i2_165_1']
#
#
#
# DFNLayout 33 broadcast= block= par=ax1_1291_1289=[0:2:1] ax2_1292_1289=[0:33:1] free=k1_1293_1289=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 1294 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_1291_1289', 'ax2_1292_1289', 'k1_1293_1289']
# 	r         |V2 $1295[ax1_1291_1289,ax2_1292_1289] = reduce_maximum(|V2 $1294[ax1_1291_1289,ax2_1292_1289,k1_1293_1289], {k1_1293_1289=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_softmax/Softmax
# 	s 1296 t1290   [2, 33] [P,P] ['ax1_1291_1289', 'ax2_1292_1289']
#
#
#
# DFNLayout 34 broadcast=k2_1300_1289=[0:33:1] block= par=ax1_1298_1289=[0:2:1] ax2_1299_1289=[0:33:1] free=k2_1300_1289=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 1302 t1290   [2, 33] [P,P] ['ax1_1298_1289', 'ax2_1299_1289']
# 	l 1301 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_1298_1289', 'ax2_1299_1289', 'k2_1300_1289']
# 	r         |V2 $1305[ax1_1298_1289,ax2_1299_1289] = reduce_add(|V2 $1304[ax1_1298_1289,ax2_1299_1289,k2_1300_1289], {k2_1300_1289=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_softmax/Softmax
# 	s 1306 t1297   [2, 33] [P,P] ['ax1_1298_1289', 'ax2_1299_1289']
#
#
#
# DFNLayout 35 broadcast=ax3_1310_1289=[0:33:1] block= par=ax1_1308_1289=[0:2:1] ax2_1309_1289=[0:33:1] free=ax3_1310_1289=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 1314 t1297   [2, 33] [P,P] ['ax1_1308_1289', 'ax2_1309_1289']
# 	l 1312 t1290   [2, 33] [P,P] ['ax1_1308_1289', 'ax2_1309_1289']
# 	l 1311 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_1308_1289', 'ax2_1309_1289', 'ax3_1310_1289']
# 	s 1317 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_softmax/Softmax:0   [2, 33, 33] [P,P,F] ['ax1_1308_1289', 'ax2_1309_1289', 'ax3_1310_1289']
#
#
#
# TensorContractLayout 36 block= load_par=c_177=[0:192:1] store_par=m_177_0=[0:2:1] m_177_1=[0:96:1] free=w_177=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=16384)
# 	l 1348 t1346  const [192] [P] ['96m_177_0+m_177_1']
# 	l 1325 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose_1/transpose:0   [192, 33] [P,F] ['c_177', 'w_177']
# 	l 1335 t1333  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_177', '96m_177_0+m_177_1']
# 	r           |V2 $6393[w_177,m_177_0,m_177_1] = tensor_contract_multiply_add(|V2 $1325[w_177,m_177_0,m_177_1,c_177], |V2 $1335[w_177,m_177_0,m_177_1,c_177], contract={c_177=[0:192:1]}, lhs_free={w_177=[0:33:1]}, rhs_free={m_177_0=[0:2:1],m_177_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/Conv1d_9/aten__convolution/conv1d
# 	s 6544 t1355   [2, 96, 33] [P,P,F] ['m_177_0', 'm_177_1', 'w_177']
#
#
#
# TensorContractLayout 37 block=i0_186=[0:2:1] load_par=i3_186=[0:33:1] store_par=i2_186=[0:96:1] free=i1_186=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=3168)
# 	l 1374 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_softmax/Softmax:0   [2, 33, 33] [B,F,P] ['i0_186', 'i1_186', 'i3_186']
# 	l 1359 t1355   [2, 96, 33] [B,F,P] ['i0_186', 'i2_186', 'i3_186']
# 	r           |V2 $6394[i0_186,i1_186,i2_186] = tensor_contract_multiply_add(|V2 $1374[i0_186,i1_186,i2_186,i3_186], |V2 $1359[i0_186,i1_186,i2_186,i3_186], contract={i3_186=[0:33:1]}, lhs_free={i1_186=[0:33:1]}, rhs_free={i2_186=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul_2/MatMul
# 	s 6549 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul_2/MatMul:0   [2, 33, 96] [B,F,P] ['i0_186', 'i1_186', 'i2_186']
#
#
#
# TensorContractLayout 38 block=i0_195=[0:2:1] i1_195=[0:33:1] load_par=i3_195=[0:65:1] store_par=i2_195=[0:96:1] free=
# layout_profile(block_axes_tripcount=66, parallel_axes_tripcount=6240)
# 	l 1535 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul_2/MatMul:0   [2, 33, 96] [B,B,P] ['i0_195', 'i1_195', 'i2_195']
# 	l 1507 TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_softmax/Softmax:0   [2, 33, 33] [B,B,P] ['i0_195', 'i1_195', 'i1_195+i3_195-32']
# 	l 1525 t1522  const [2, 96, 65] [B,F,P] ['i0_195', 'i2_195', 'i3_195']
# 	r           |V2 $6395[i0_195,i1_195,i2_195] = tensor_contract_multiply_add(|V2 $1507[i0_195,i1_195,i2_195,i3_195], |V2 $1525[i0_195,i1_195,i2_195,i3_195], contract={i3_195=[0:65:1]}, lhs_free={i1_195=[0:33:1]}, rhs_free={i2_195=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/aten_matmul_3/MatMul
# 	s 6555 t1543   [2, 96, 33] [B,P,B] ['i0_195', 'i2_195', 'i1_195']
#
#
#
# TensorContractLayout 39 block=c_203_0=[0:2:1] load_par=c_203_1=[0:96:1] store_par=m_203=[0:192:1] free=w_203=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 1573 t1571  const [192] [P] ['m_203']
# 	l 1580 TextEncoder_8/Encoder_31/LayerNorm_64/aten_transpose_1/transpose:0   [192, 33] [P,F] ['m_203', 'w_203']
# 	l 1547 t1543   [2, 96, 33] [B,P,F] ['c_203_0', 'c_203_1', 'w_203']
# 	l 1560 t1558  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', '96c_203_0+c_203_1', 'm_203']
# 	r           |V2 $6396[w_203,m_203] = tensor_contract_multiply_add(|V2 $1547[w_203,m_203,c_203_0,c_203_1], |V2 $1560[w_203,m_203,c_203_0,c_203_1], contract={c_203_0=[0:2:1],c_203_1=[0:96:1]}, lhs_free={w_203=[0:33:1]}, rhs_free={m_203=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_65/Conv1d_305/aten__convolution/conv1d
# 	s 6560 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose/transpose:0   [33, 192] [F,P] ['w_203', 'm_203']
#
#
#
# DFNLayout 40 broadcast= block= par=i1_208=[0:33:1] free=i2_208=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1589 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_208', 'i2_208']
# 	r       |V2 $1590[i1_208] = reduce_add(|V2 $1589[i1_208,i2_208], {i2_208=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/moments/mean
# 	s 1595 TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/moments/mean:0   [33] [P] ['i1_208']
#
#
#
# DFNLayout 41 broadcast=i2_211=[0:192:1] block= par=i1_211=[0:33:1] free=i2_211=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1597 TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/moments/mean:0   [33] [P] ['i1_211']
# 	l 1599 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_211', 'i2_211']
# 	s 1603 subtract2:0   [33, 192] [P,F] ['i1_211', 'i2_211']
#
#
#
# DFNLayout 42 broadcast= block= par=i1_213=[0:33:1] free=i2_213=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1604 subtract2:0   [33, 192] [P,F] ['i1_213', 'i2_213']
# 	r       |V2 $1611[i1_213] = reduce_add(|V2 $1607[i1_213,i2_213], {i2_213=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/moments/variance
# 	s 1632 TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/batchnorm/Rsqrt:0   [33] [P] ['i1_213']
#
#
#
# DFNLayout 43 broadcast=i2_217_6879=[0:192:1] block= par=i1_217_6879=[0:33:1] free=i2_217_6879=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1645 TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/moments/mean:0   [33] [P] ['i1_217_6879']
# 	s 6877 t6876   [33, 192] [P,F] ['i1_217_6879', 'i2_217_6879']
#
#
#
# DFNLayout 44 broadcast=i2_217_6883=[0:192:1] block= par=i1_217_6883=[0:33:1] free=i2_217_6883=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1667 cast0:0   [33] [P] ['i1_217_6883']
# 	s 6881 t6880   [33, 192] [P,F] ['i1_217_6883', 'i2_217_6883']
#
#
#
# TensorContractLayout 45 block= load_par= store_par=i2_217=[0:192:1] free=i1_217=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=128)
# 	l 6882 t6880   [33, 192] [F,P] ['i1_217', 'i2_217']
# 	l 6878 t6876   [33, 192] [F,P] ['i1_217', 'i2_217']
# 	l 1634 TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/batchnorm/Rsqrt:0   [33] [F] ['i1_217']
# 	l 1635 t1633  const [192] [F] ['i2_217']
# 	r       |V2 $6397[i1_217,i2_217] = tensor_contract_multiply_add(|V2 $1634[i1_217,i2_217], |V2 $1635[i1_217,i2_217], contract={}, lhs_free={i1_217=[0:33:1]}, rhs_free={i2_217=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_69/aten_layer_norm/batchnorm/mul
# 	l 1639 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose/transpose:0   [33, 192] [F,P] ['i1_217', 'i2_217']
# 	l 1650 t1644  const [192] [P] ['i2_217']
# 	s 6561 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose_1/transpose:0   [192, 33] [P,F] ['i2_217', 'i1_217']
# 	s 1673 TextEncoder_8/Encoder_31/FFN_70/aten_mul/mul:0   [192, 33] [P,F] ['i2_217', 'i1_217']
#
#
#
# TensorContractLayout 46 block=s_225=[0:3:1] load_par=c_225=[0:192:1] store_par=m_225=[0:768:1] free=w_225=[0:33:1]
# layout_profile(block_axes_tripcount=36, parallel_axes_tripcount=16384)
# 	l 1713 cast0:0   [33] [F] ['w_225']
# 	l 1698 t1696  const [768] [P] ['m_225']
# 	l 1684 TextEncoder_8/Encoder_31/FFN_70/aten_mul/mul:0   [192, 33] [P,F] ['c_225', 'w_225+s_225-1']
# 	l 1685 t1683  const [1, 3, 192, 768] [F,B,P,F] ['0', 's_225', 'c_225', 'm_225']
# 	r           |V2 $6398[w_225,m_225] = tensor_contract_multiply_add(|V2 $1684[w_225,m_225,c_225,s_225], |V2 $1685[w_225,m_225,c_225,s_225], contract={c_225=[0:192:1],s_225=[0:3:1]}, lhs_free={w_225=[0:33:1]}, rhs_free={m_225=[0:768:1]}) # dl = TextEncoder_8/Encoder_31/FFN_70/Conv1d_14/aten__convolution/conv1d
# 	s 1719 TextEncoder_8/Encoder_31/FFN_70/aten_mul_1/mul:0   [768, 33] [P,F] ['m_225', 'w_225']
#
#
#
# TensorContractLayout 47 block=s_231=[0:3:1] load_par=c_231=[0:768:1] store_par=m_231=[0:192:1] free=w_231=[0:33:1]
# layout_profile(block_axes_tripcount=36, parallel_axes_tripcount=16384)
# 	l 1755 cast0:0   [33] [F] ['w_231']
# 	l 1744 t1742  const [192] [P] ['m_231']
# 	l 1762 TextEncoder_8/Encoder_31/LayerNorm_69/aten_transpose_1/transpose:0   [192, 33] [P,F] ['m_231', 'w_231']
# 	l 1730 TextEncoder_8/Encoder_31/FFN_70/aten_mul_1/mul:0   [768, 33] [P,F] ['c_231', 'w_231+s_231-1']
# 	l 1731 t1729  const [1, 3, 768, 192] [F,B,P,F] ['0', 's_231', 'c_231', 'm_231']
# 	r           |V2 $6399[w_231,m_231] = tensor_contract_multiply_add(|V2 $1730[w_231,m_231,c_231,s_231], |V2 $1731[w_231,m_231,c_231,s_231], contract={c_231=[0:768:1],s_231=[0:3:1]}, lhs_free={w_231=[0:33:1]}, rhs_free={m_231=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/FFN_70/Conv1d_28/aten__convolution/conv1d
# 	s 6568 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose/transpose:0   [33, 192] [F,P] ['w_231', 'm_231']
#
#
#
# DFNLayout 48 broadcast= block= par=i1_237=[0:33:1] free=i2_237=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1771 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_237', 'i2_237']
# 	r       |V2 $1772[i1_237] = reduce_add(|V2 $1771[i1_237,i2_237], {i2_237=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/moments/mean
# 	s 1777 TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/moments/mean:0   [33] [P] ['i1_237']
#
#
#
# DFNLayout 49 broadcast=i2_240=[0:192:1] block= par=i1_240=[0:33:1] free=i2_240=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1779 TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/moments/mean:0   [33] [P] ['i1_240']
# 	l 1781 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose/transpose:0   [33, 192] [P,F] ['i1_240', 'i2_240']
# 	s 1785 subtract3:0   [33, 192] [P,F] ['i1_240', 'i2_240']
#
#
#
# DFNLayout 50 broadcast= block= par=i1_242=[0:33:1] free=i2_242=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1786 subtract3:0   [33, 192] [P,F] ['i1_242', 'i2_242']
# 	r       |V2 $1793[i1_242] = reduce_add(|V2 $1789[i1_242,i2_242], {i2_242=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/moments/variance
# 	s 1814 TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/batchnorm/Rsqrt:0   [33] [P] ['i1_242']
#
#
#
# DFNLayout 51 broadcast=i2_246_6887=[0:192:1] block= par=i1_246_6887=[0:33:1] free=i2_246_6887=[0:192:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=33)
# 	l 1827 TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/moments/mean:0   [33] [P] ['i1_246_6887']
# 	s 6885 t6884   [33, 192] [P,F] ['i1_246_6887', 'i2_246_6887']
#
#
#
# TensorContractLayout 52 block= load_par= store_par=i2_246=[0:192:1] free=i1_246=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=128)
# 	l 6886 t6884   [33, 192] [F,P] ['i1_246', 'i2_246']
# 	l 1816 TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/batchnorm/Rsqrt:0   [33] [F] ['i1_246']
# 	l 1817 t1815  const [192] [F] ['i2_246']
# 	r       |V2 $6400[i1_246,i2_246] = tensor_contract_multiply_add(|V2 $1816[i1_246,i2_246], |V2 $1817[i1_246,i2_246], contract={}, lhs_free={i1_246=[0:33:1]}, rhs_free={i2_246=[0:192:1]}) # dl = TextEncoder_8/Encoder_31/LayerNorm_74/aten_layer_norm/batchnorm/mul
# 	l 1821 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose/transpose:0   [33, 192] [F,P] ['i1_246', 'i2_246']
# 	l 1832 t1826  const [192] [P] ['i2_246']
# 	s 6569 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose_1/transpose:0   [192, 33] [P,F] ['i2_246', 'i1_246']
#
#
#
# TensorContractLayout 53 block=m_254_0=[0:2:1] load_par=c_254=[0:192:1] store_par=m_254_1=[0:96:1] free=w_254=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 1882 t1880  const [192] [P] ['96m_254_0+m_254_1']
# 	l 1859 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose_1/transpose:0   [192, 33] [P,F] ['c_254', 'w_254']
# 	l 1869 t1867  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_254', '96m_254_0+m_254_1']
# 	r           |V2 $6401[w_254,m_254_0,m_254_1] = tensor_contract_multiply_add(|V2 $1859[w_254,m_254_0,m_254_1,c_254], |V2 $1869[w_254,m_254_0,m_254_1,c_254], contract={c_254=[0:192:1]}, lhs_free={w_254=[0:33:1]}, rhs_free={m_254_0=[0:2:1],m_254_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_75/Conv1d_7/aten__convolution/conv1d
# 	s 6576 reshape16:0   [2, 33, 96] [B,F,P] ['m_254_0', 'w_254', 'm_254_1']
# 	s 6589 reshape18:0   [2, 33, 96] [B,F,P] ['m_254_0', 'w_254', 'm_254_1']
#
#
#
# TensorContractLayout 54 block=m_264_0=[0:2:1] load_par=c_264=[0:192:1] store_par=m_264_1=[0:96:1] free=w_264=[0:33:1]
# layout_profile(block_axes_tripcount=4, parallel_axes_tripcount=12288)
# 	l 1934 t1932  const [192] [P] ['96m_264_0+m_264_1']
# 	l 1911 TextEncoder_8/Encoder_31/LayerNorm_74/aten_transpose_1/transpose:0   [192, 33] [P,F] ['c_264', 'w_264']
# 	l 1921 t1919  const [1, 1, 192, 192] [F,F,P,F] ['0', '0', 'c_264', '96m_264_0+m_264_1']
# 	r           |V2 $6402[w_264,m_264_0,m_264_1] = tensor_contract_multiply_add(|V2 $1911[w_264,m_264_0,m_264_1,c_264], |V2 $1921[w_264,m_264_0,m_264_1,c_264], contract={c_264=[0:192:1]}, lhs_free={w_264=[0:33:1]}, rhs_free={m_264_0=[0:2:1],m_264_1=[0:96:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_75/Conv1d_8/aten__convolution/conv1d
# 	s 6580 t1941   [2, 96, 33] [B,P,F] ['m_264_0', 'm_264_1', 'w_264']
#
#
#
# TensorContractLayout 55 block=i0_274=[0:2:1] load_par=i3_274=[0:96:1] store_par=i2_274=[0:33:1] free=i1_274=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=3168)
# 	l 1963 reshape16:0   [2, 33, 96] [B,F,P] ['i0_274', 'i1_274', 'i3_274']
# 	l 1945 t1941   [2, 96, 33] [B,P,F] ['i0_274', 'i3_274', 'i2_274']
# 	r           |V2 $6403[i0_274,i1_274,i2_274] = tensor_contract_multiply_add(|V2 $1963[i0_274,i1_274,i2_274,i3_274], |V2 $1945[i0_274,i1_274,i2_274,i3_274], contract={i3_274=[0:96:1]}, lhs_free={i1_274=[0:33:1]}, rhs_free={i2_274=[0:33:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_matmul/MatMul
# 	s 6587 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_matmul/MatMul:0   [2, 33, 33] [B,F,P] ['i0_274', 'i1_274', 'i2_274']
#
#
#
# TensorContractLayout 56 block=i0_280=[0:2:1] load_par=i3_280=[0:96:1] store_par=i2_280=[0:65:1] free=i1_280=[0:33:1]
# layout_profile(block_axes_tripcount=2, parallel_axes_tripcount=6240)
# 	l 1995 reshape18:0   [2, 33, 96] [B,F,P] ['i0_280', 'i1_280', 'i3_280']
# 	l 1996 t1993  const [2, 65, 96] [B,F,P] ['i0_280', 'i2_280', 'i3_280']
# 	r           |V2 $6404[i0_280,i1_280,i2_280] = tensor_contract_multiply_add(|V2 $1995[i0_280,i1_280,i2_280,i3_280], |V2 $1996[i0_280,i1_280,i2_280,i3_280], contract={i3_280=[0:96:1]}, lhs_free={i1_280=[0:33:1]}, rhs_free={i2_280=[0:65:1]}) # dl = TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_matmul_1/MatMul
# 	s 6825 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_view_3/Reshape:0   [2, 2113] [B,F] ['i0_280', '66i1_280+i2_280-32']
#
#
#
# DFNLayout 57 broadcast=i1_285=[0:2:1] block=i2_285_0=[0:33:1] par=i2_285_1=[0:33:1] free=i1_285=[0:2:1]
# layout_profile(block_axes_tripcount=33, parallel_axes_tripcount=33)
# 	l 2013 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_view_3/Reshape:0   [2, 2113] [F,P] ['i1_285', '65i2_285_0+i2_285_1']
# 	l 2130 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_matmul/MatMul:0   [2, 33, 33] [F,B,P] ['i1_285', 'i2_285_0', 'i2_285_1']
# 	l 2135 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_eq/Equal:0   [33, 33] [B,P] ['i2_285_0', 'i2_285_1']
# 	l 2140 t111  const [1, 2, 33, 33] [F,F,B,P] ['0', 'i1_285', 'i2_285_0', 'i2_285_1']
# 	s 2161 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_masked_fill/Select:0   [2, 33, 33] [F,B,P] ['i1_285', 'i2_285_0', 'i2_285_1']
#
#
#
# DFNLayout 58 broadcast= block= par=ax1_2164_2162=[0:2:1] ax2_2165_2162=[0:33:1] free=k1_2166_2162=[0:33:1]
# layout_profile(block_axes_tripcount=1, parallel_axes_tripcount=66)
# 	l 2167 TextEncoder_8/Encoder_31/MultiHeadAttention_75/aten_masked_fill/Select:0   [2, 33, 33] [P,P,F] ['ax1_2164_2162', 'ax2_2165_2162', 'k1_2166_2162']
# ...
# [ERROR] cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/convert.py", line 413, in op_converter
#     neuron_function = self.subgraph_compiler(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 266, in trace
#     metaneff, neff = compile_from_neff(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 355, in compile_from_neff
#     from torch_neuron.proto import metaneff_pb2
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/proto/metaneff_pb2.py", line 5, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# .
# INFO:Neuron:Compiling function _NeuronGraph$1055 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1055 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py310/bin/neuron-cc compile /tmp/tmpvg4ayqhy/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpvg4ayqhy/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 51], "float32"], "tensor.1:0": [[1, 384, 51], "float32"], "tensor.7:0": [[1, 384, 51], "float32"], "tensor.13:0": [[1, 384, 51], "float32"], "4:0": [[1, 192, 51], "float32"], "5:0": [[1, 1, 51], "float32"], "6:0": [[1, 96, 51], "float32"], "7:0": [[1, 96, 51], "float32"], "8:0": [[1, 192, 51], "float32"], "9:0": [[1, 192, 51], "float32"], "10:0": [[1, 192, 51], "float32"], "11:0": [[1, 1, 51, 33], "float32"]}, "outputs": ["Generator_165/aten_tanh/Tanh:0", "Identity:0", "Identity_1:0", "ResidualCouplingBlock_148/ResidualCouplingLayer_23/aten_cat/concat:0", "Identity_2:0", "Identity_3:0", "Identity_4:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py310/bin/neuron-cc compile /tmp/tmpvg4ayqhy/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpvg4ayqhy/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 51], "float32"], "tensor.1:0": [[1, 384, 51], "float32"], "tensor.7:0": [[1, 384, 51], "float32"], "tensor.13:0": [[1, 384, 51], "float32"], "4:0": [[1, 192, 51], "float32"], "5:0": [[1, 1, 51], "float32"], "6:0": [[1, 96, 51], "float32"], "7:0": [[1, 96, 51], "float32"], "8:0": [[1, 192, 51], "float32"], "9:0": [[1, 192, 51], "float32"], "10:0": [[1, 192, 51], "float32"], "11:0": [[1, 1, 51, 33], "float32"]}, "outputs": ["Generator_165/aten_tanh/Tanh:0", "Identity:0", "Identity_1:0", "ResidualCouplingBlock_148/ResidualCouplingLayer_23/aten_cat/concat:0", "Identity_2:0", "Identity_3:0", "Identity_4:0"]} --verbose 35'
# ....................
# Compiler status PASS
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1055; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1055; falling back to native python function call
# ERROR:Neuron:cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/convert.py", line 413, in op_converter
#     neuron_function = self.subgraph_compiler(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 266, in trace
#     metaneff, neff = compile_from_neff(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 355, in compile_from_neff
#     from torch_neuron.proto import metaneff_pb2
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/proto/metaneff_pb2.py", line 5, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# [ERROR] cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/convert.py", line 413, in op_converter
#     neuron_function = self.subgraph_compiler(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 266, in trace
#     metaneff, neff = compile_from_neff(
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/decorators.py", line 355, in compile_from_neff
#     from torch_neuron.proto import metaneff_pb2
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/proto/metaneff_pb2.py", line 5, in <module>
#     from google.protobuf.internal import builder as _builder
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (/home/ubuntu/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/google/protobuf/internal/__init__.py)
# INFO:Neuron:Number of arithmetic operators (post-compilation) before = 2009, compiled = 0, percent compiled = 0.0%
# [INFO] Number of arithmetic operators (post-compilation) before = 2009, compiled = 0, percent compiled = 0.0%
# INFO:Neuron:The neuron partitioner created 31 sub-graphs
# [INFO] The neuron partitioner created 31 sub-graphs
# INFO:Neuron:Neuron successfully compiled 0 sub-graphs, Total fused subgraphs = 31, Percent of model sub-graphs successfully compiled = 0.0%
# [INFO] Neuron successfully compiled 0 sub-graphs, Total fused subgraphs = 31, Percent of model sub-graphs successfully compiled = 0.0%
# INFO:Neuron:Compiled these operators (and operator counts) to Neuron:
# [INFO] Compiled these operators (and operator counts) to Neuron:
# INFO:Neuron:Not compiled operators (and operator counts) to Neuron:
# [INFO] Not compiled operators (and operator counts) to Neuron:
# INFO:Neuron: => aten::Int: 219 [supported]
# [INFO]  => aten::Int: 219 [supported]
# INFO:Neuron: => aten::ScalarImplicit: 3 [supported]
# [INFO]  => aten::ScalarImplicit: 3 [supported]
# INFO:Neuron: => aten::__and__: 3 [supported]
# [INFO]  => aten::__and__: 3 [supported]
# INFO:Neuron: => aten::_convolution: 187 [supported]
# [INFO]  => aten::_convolution: 187 [supported]
# INFO:Neuron: => aten::_weight_norm: 108 [supported]
# [INFO]  => aten::_weight_norm: 108 [supported]
# INFO:Neuron: => aten::add: 155 [supported]
# [INFO]  => aten::add: 155 [supported]
# INFO:Neuron: => aten::add_: 11 [supported]
# [INFO]  => aten::add_: 11 [supported]
# INFO:Neuron: => aten::arange: 3 [supported]
# [INFO]  => aten::arange: 3 [supported]
# INFO:Neuron: => aten::bitwise_not: 3 [supported]
# [INFO]  => aten::bitwise_not: 3 [supported]
# INFO:Neuron: => aten::cat: 7 [supported]
# [INFO]  => aten::cat: 7 [supported]
# INFO:Neuron: => aten::ceil: 1 [supported]
# [INFO]  => aten::ceil: 1 [supported]
# INFO:Neuron: => aten::clamp_min: 1 [supported]
# [INFO]  => aten::clamp_min: 1 [supported]
# INFO:Neuron: => aten::contiguous: 6 [supported]
# [INFO]  => aten::contiguous: 6 [supported]
# INFO:Neuron: => aten::copy_: 3 [supported]
# [INFO]  => aten::copy_: 3 [supported]
# INFO:Neuron: => aten::cumsum: 7 [supported]
# [INFO]  => aten::cumsum: 7 [supported]
# INFO:Neuron: => aten::detach: 1 [supported]
# [INFO]  => aten::detach: 1 [supported]
# INFO:Neuron: => aten::div: 28 [supported]
# [INFO]  => aten::div: 28 [supported]
# INFO:Neuron: => aten::dropout: 52 [supported]
# [INFO]  => aten::dropout: 52 [supported]
# INFO:Neuron: => aten::embedding: 1 [not supported]
# [INFO]  => aten::embedding: 1 [not supported]
# INFO:Neuron: => aten::eq: 6 [supported]
# [INFO]  => aten::eq: 6 [supported]
# INFO:Neuron: => aten::exp: 7 [supported]
# [INFO]  => aten::exp: 7 [supported]
# INFO:Neuron: => aten::fill_: 18 [supported]
# [INFO]  => aten::fill_: 18 [supported]
# INFO:Neuron: => aten::flip: 8 [supported]
# [INFO]  => aten::flip: 8 [supported]
# INFO:Neuron: => aten::gather: 21 [not supported]
# [INFO]  => aten::gather: 21 [not supported]
# INFO:Neuron: => aten::ge: 6 [supported]
# [INFO]  => aten::ge: 6 [supported]
# INFO:Neuron: => aten::gelu: 24 [supported]
# [INFO]  => aten::gelu: 24 [supported]
# INFO:Neuron: => aten::index: 15 [not supported]
# [INFO]  => aten::index: 15 [not supported]
# INFO:Neuron: => aten::index_put_: 6 [not supported]
# [INFO]  => aten::index_put_: 6 [not supported]
# INFO:Neuron: => aten::layer_norm: 36 [supported]
# [INFO]  => aten::layer_norm: 36 [supported]
# INFO:Neuron: => aten::le: 3 [supported]
# [INFO]  => aten::le: 3 [supported]
# INFO:Neuron: => aten::leaky_relu: 77 [supported]
# [INFO]  => aten::leaky_relu: 77 [supported]
# INFO:Neuron: => aten::lt: 3 [supported]
# [INFO]  => aten::lt: 3 [supported]
# INFO:Neuron: => aten::masked_fill: 6 [supported]
# [INFO]  => aten::masked_fill: 6 [supported]
# INFO:Neuron: => aten::matmul: 26 [supported]
# [INFO]  => aten::matmul: 26 [supported]
# INFO:Neuron: => aten::max: 1 [supported]
# [INFO]  => aten::max: 1 [supported]
# INFO:Neuron: => aten::mul: 183 [supported]
# [INFO]  => aten::mul: 183 [supported]
# INFO:Neuron: => aten::neg: 11 [supported]
# [INFO]  => aten::neg: 11 [supported]
# INFO:Neuron: => aten::pad: 58 [not supported]
# [INFO]  => aten::pad: 58 [not supported]
# INFO:Neuron: => aten::permute: 3 [supported]
# [INFO]  => aten::permute: 3 [supported]
# INFO:Neuron: => aten::pow: 9 [supported]
# [INFO]  => aten::pow: 9 [supported]
# INFO:Neuron: => aten::randn: 1 [not supported]
# [INFO]  => aten::randn: 1 [not supported]
# INFO:Neuron: => aten::randn_like: 1 [not supported]
# [INFO]  => aten::randn_like: 1 [not supported]
# INFO:Neuron: => aten::relu: 6 [supported]
# [INFO]  => aten::relu: 6 [supported]
# INFO:Neuron: => aten::reshape: 3 [supported]
# [INFO]  => aten::reshape: 3 [supported]
# INFO:Neuron: => aten::rsub: 6 [supported]
# [INFO]  => aten::rsub: 6 [supported]
# INFO:Neuron: => aten::select: 45 [supported]
# [INFO]  => aten::select: 45 [supported]
# INFO:Neuron: => aten::size: 78 [supported]
# [INFO]  => aten::size: 78 [supported]
# INFO:Neuron: => aten::slice: 182 [supported]
# [INFO]  => aten::slice: 182 [supported]
# INFO:Neuron: => aten::softmax: 12 [supported]
# [INFO]  => aten::softmax: 12 [supported]
# INFO:Neuron: => aten::softplus: 3 [supported]
# [INFO]  => aten::softplus: 3 [supported]
# INFO:Neuron: => aten::split: 1 [supported]
# [INFO]  => aten::split: 1 [supported]
# INFO:Neuron: => aten::split_with_sizes: 8 [supported]
# [INFO]  => aten::split_with_sizes: 8 [supported]
# INFO:Neuron: => aten::sqrt: 3 [supported]
# [INFO]  => aten::sqrt: 3 [supported]
# INFO:Neuron: => aten::squeeze: 2 [supported]
# [INFO]  => aten::squeeze: 2 [supported]
# INFO:Neuron: => aten::sub: 96 [supported]
# [INFO]  => aten::sub: 96 [supported]
# INFO:Neuron: => aten::sum: 4 [supported]
# [INFO]  => aten::sum: 4 [supported]
# INFO:Neuron: => aten::tanh: 1 [supported]
# [INFO]  => aten::tanh: 1 [supported]
# INFO:Neuron: => aten::to: 9 [supported]
# [INFO]  => aten::to: 9 [supported]
# INFO:Neuron: => aten::transpose: 114 [supported]
# [INFO]  => aten::transpose: 114 [supported]
# INFO:Neuron: => aten::unsqueeze: 31 [supported]
# [INFO]  => aten::unsqueeze: 31 [supported]
# INFO:Neuron: => aten::view: 50 [supported]
# [INFO]  => aten::view: 50 [supported]
# INFO:Neuron: => aten::zeros_like: 27 [supported]
# [INFO]  => aten::zeros_like: 27 [supported]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 2
#       1 # torch_neuron.trace 사용
# ----> 2 traced_model = torch_neuron.trace(wrapped_model,
#       3                                   (x_tst, x_tst_lengths,
#       4                                    noise_scale, noise_scale_w, length_scale))
#
# File ~/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/convert.py:217, in trace(func, example_inputs, fallback, op_whitelist, minimum_segment_size, subgraph_builder_function, subgraph_inputs_pruning, skip_compiler, debug_must_trace, allow_no_ops_on_neuron, compiler_workdir, dynamic_batch_size, compiler_timeout, single_fusion_ratio_threshold, _neuron_trace, compiler_args, optimizations, separate_weights, verbose, **kwargs)
#     215     logger.debug("skip_inference_context - trace with fallback at {}".format(get_file_and_line()))
#     216     neuron_graph = cu.compile_fused_operators(neuron_graph, **compile_kwargs)
# --> 217 cu.stats_post_compiler(neuron_graph)
#     219 # Wrap the compiled version of the model in a script module. Note that this is
#     220 # necessary for torch==1.8.1 due to the usage of `torch.classes.model.Model`. The
#     221 # custom class must be a submodule of the traced graph.
#     222 neuron_graph = AwsNeuronGraphModule(neuron_graph)
#
# File ~/miniconda3/envs/vits-conda-py310/lib/python3.10/site-packages/torch_neuron/convert.py:530, in CompilationUnit.stats_post_compiler(self, neuron_graph)
#     526             logger.info(' => {}: {} {}'.format(
#     527                 name, remaining_count, supported_string))
#     529 if succesful_compilations == 0 and not self.allow_no_ops_on_neuron:
# --> 530     raise RuntimeError(
#     531         "No operations were successfully partitioned and compiled to neuron for this model - aborting trace!")
#     533 if percent_operations_compiled < 50.0:
#     534     logger.warning(
#     535         "torch.neuron.trace was unable to compile > 50% of the operators in the compiled model!")
#
# RuntimeError: No operations were successfully partitioned and compiled to neuron for this model - aborting trace!
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
# 트레이스된 모델 저장
torch.jit.save(traced_model, "traced_vits_model_neuron.pt")

# %% [markdown]
# ## 모델 추론

# %%
# Prepare input
# stn_tst = get_text("VITS is Awesome!", hps)
stn_tst = get_text("Melon is a great fruit in summer for everybody", hps)

x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
# Convert scalar value to tensor
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

# %%
# inference
traced_output = traced_model(x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale)
print("output shape:", traced_output[0].shape)

ipd.display(ipd.Audio(traced_output, rate=hps.data.sampling_rate, normalize=False))

# %% [markdown]
# ## 모델 로딩후 추론 테스트

# %%
import torch
import torch_neuron
import commons
import utils
from text import text_to_sequence

hps = utils.get_hparams_from_file("./configs/ljs_base.json")

def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

def load_neuron_model(model_path):
    device = torch.device("cpu")  # 먼저 CPU에 로드
    model = torch.jit.load(model_path, map_location=device)
    return torch_neuron.DataParallel(model)


# Prepare input
stn_tst = get_text("VITS is Awesome!", hps)

x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
# Convert scalar value to tensor
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

# %%
# 사용 예시
model_path = "traced_vits_model_neuron.pt"
loaded_neuron_model = load_neuron_model(model_path)

# %%
# inference
traced_output = loaded_neuron_model(x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale)
print("output shape:", traced_output[0].shape)

# %% [markdown]
# ## Neuron Analyzer

# %%
import torch
import torch_neuron
from torch_neuron import analyze_model

analyzer = analyze_model(wrapped_model, (x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale))
