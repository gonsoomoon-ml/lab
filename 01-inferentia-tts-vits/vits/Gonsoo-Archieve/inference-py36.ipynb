# %% [markdown]
# # Inference VITS Model on CPU and Compilation on Neuron
# * Conditional Variational Autoencoder with Adversarial Learning for End-to-End Text-to-Speech
#     * Git: https://github.com/jaywalnut310/vits.git

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

# %% [markdown]
# ## LJ Speech

# %%
hps = utils.get_hparams_from_file("./configs/ljs_base.json")
# Out:
# ['english_cleaners2']

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model)
_ = net_g.eval()

_ = utils.load_checkpoint("models/pretrained_ljs.pth", net_g, None)

# %%
def play_tts_cpu(stn_tst, net_g):
    with torch.no_grad():
        x_tst = stn_tst.unsqueeze(0)
        x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
        # audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
        audio = net_g(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()    
        ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
    return audio

stn_tst = get_text("VITS is Awesome!", hps)    
audio = play_tts_cpu(stn_tst, net_g)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
stn_tst = get_text("VITS is Awesome!, How are you doing today?", hps)    
audio = play_tts_cpu(stn_tst, net_g)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Neuron Complie Test

# %%
import torch
import torch_neuron
from torch_neuron import analyze_model

# %%
# wrapping model
class VITSWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x, x_lengths, noise_scale, noise_scale_w, length_scale):
        return self.model.infer(x, x_lengths, 
                                noise_scale=noise_scale.item(),
                                noise_scale_w=noise_scale_w.item(), 
                                length_scale=length_scale.item())

wrapped_model = VITSWrapper(net_g)

# %%
# create data
# stn_tst = get_text("VITS is Awesome!", hps)
# print("stn_tst: ", stn_tst)
stn_tst = torch.randint(low=1, high=10, size=(33,), dtype=torch.int64)
x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])

# 스칼라 값을 텐서로 변환
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

print("x_tst: ", x_tst)
print("x_tst shape: ", x_tst.shape)
print("x_tst_length shape: ", x_tst_lengths.shape)
print("x_tst_length: ", x_tst_lengths)
# Out:
# x_tst:  tensor([[7, 5, 9, 8, 9, 8, 5, 8, 4, 4, 5, 2, 8, 3, 1, 1, 9, 1, 7, 4, 2, 9, 9, 4,
#          3, 1, 9, 3, 5, 7, 5, 3, 7]])
# x_tst shape:  torch.Size([1, 33])
# x_tst_length shape:  torch.Size([1])
# x_tst_length:  tensor([33])

# %%
# torch_neuron.trace 사용
traced_model = torch_neuron.trace(wrapped_model, 
                                  (x_tst, x_tst_lengths, 
                                   noise_scale, noise_scale_w, length_scale))
# Out:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:9: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if __name__ == '__main__':
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:10: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   # Remove the CWD from sys.path while we load stuff.
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:11: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   # This is added back by InteractiveShellApp.init_path()
# /home/ubuntu/vits/attentions.py:157: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert t_s == t_t, "Relative attention is only available for self-attention."
# /home/ubuntu/vits/attentions.py:202: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_length = max(length - (self.window_size + 1), 0)
# /home/ubuntu/vits/attentions.py:203: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   slice_start_position = max((self.window_size + 1) - length, 0)
# /home/ubuntu/vits/attentions.py:205: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if pad_length > 0:
# /home/ubuntu/vits/transforms.py:105: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if torch.min(inputs) < left or torch.max(inputs) > right:
# /home/ubuntu/vits/transforms.py:110: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_bin_width * num_bins > 1.0:
# /home/ubuntu/vits/transforms.py:112: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if min_bin_height * num_bins > 1.0:
# /home/ubuntu/vits/transforms.py:164: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert (discriminant >= 0).all()
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%7880 : Float(1, 192, 46, strides=[8832, 1, 192], requires_grad=0, device=cpu) = aten::randn_like(%m_p, %7875, %7876, %7877, %7878, %7879) # /home/ubuntu/vits/models.py:547:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _module_class,
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# With rtol=1e-05 and atol=1e-05, found 11763 element(s) (out of 11776) whose difference(s) exceeded the margin of error (including 0 nan comparisons). The greatest difference was 0.22628916800022125 (0.1551833599805832 vs. -0.07110580801963806), which occurred at index (0, 0, 1931).
#   _module_class,
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# With rtol=1e-05 and atol=1e-05, found 60 element(s) (out of 1518) whose difference(s) exceeded the margin of error (including 0 nan comparisons). The greatest difference was 1.0 (0.0 vs. 1.0), which occurred at index (0, 0, 3, 1).
#   _module_class,
# INFO:Neuron:There are 62 ops of 8 different types in the TorchScript that are not compiled by neuron-cc: prim::CallFunction, aten::randn_like, aten::clamp_min, aten::index_put_, aten::gather, aten::index, aten::randn, aten::embedding, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/compiler/neuron-cc/neuron-cc-ops/neuron-cc-ops-pytorch.html)
# [INFO] There are 62 ops of 8 different types in the TorchScript that are not compiled by neuron-cc: prim::CallFunction, aten::randn_like, aten::clamp_min, aten::index_put_, aten::gather, aten::index, aten::randn, aten::embedding, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/compiler/neuron-cc/neuron-cc-ops/neuron-cc-ops-pytorch.html)
# INFO:Neuron:Number of arithmetic operators (pre-compilation) before = 2066, fused = 2014, percent fused = 97.48%
# [INFO] Number of arithmetic operators (pre-compilation) before = 2066, fused = 2014, percent fused = 97.48%
# [WARNING] From /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/ops/aten.py:2277: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:Neuron:Compiling function _NeuronGraph$1026 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1026 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config {"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config {"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]} --verbose 35'
# INFO:Neuron:Compile command returned: 1
# [INFO] Compile command returned: 1
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1026; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1026; falling back to native python function call
# ERROR:Neuron:neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]}' --verbose 35
# [ERROR] neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp7uy7xa6e/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp7uy7xa6e/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 33, 192], "float32"], "1:0": [[1], "int64"]}, "outputs": ["TextEncoder_8/aten_to/Cast:0", "TextEncoder_8/aten_split/split:0", "TextEncoder_8/aten_split/split:1", "StochasticDurationPredictor_10/aten_mul/mul:0", "StochasticDurationPredictor_10/aten_detach_1/Const:0", "StochasticDurationPredictor_10/aten_detach_2/Const:0"]}' --verbose 35
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1027; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1027; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1028; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1028; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# INFO:Neuron:Compiling function _NeuronGraph$1029 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1029 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp6q8j3j94/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp6q8j3j94/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_48/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_48/aten_slice_1/StridedSlice:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp6q8j3j94/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp6q8j3j94/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_48/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_48/aten_slice_1/StridedSlice:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1030 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1030 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp1hc1k7_u/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp1hc1k7_u/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_48/aten_add_3/add:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp1hc1k7_u/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp1hc1k7_u/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_48/aten_add_3/add:0"]} --verbose 35'
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1031; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1031; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1032; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1032; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# INFO:Neuron:Compiling function _NeuronGraph$1033 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1033 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp25h0r_zc/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp25h0r_zc/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_50/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_50/aten_slice_1/StridedSlice:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp25h0r_zc/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp25h0r_zc/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_50/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_50/aten_slice_1/StridedSlice:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1034 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1034 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmptsncoerd/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmptsncoerd/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_50/aten_add_3/add:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmptsncoerd/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmptsncoerd/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_50/aten_add_3/add:0"]} --verbose 35'
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1035; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1035; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1036; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1036; falling back to native python function call
# ERROR:Neuron:list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# [ERROR] list index out of range
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 78, in trace
#     passes.pass_remove_mutation(jit_trace)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 780, in pass_remove_mutation
#     storage, mutated = view_update_backward(graph, node, replacement)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 688, in view_update_backward
#     original, updated, insertions = handler(graph, node, updated)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 297, in undo_select
#     left = create_slice(graph, tensor, dim, zero, index, one)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/passes/remove_mutation.py", line 162, in create_slice
#     tensor_size = size[dim_value]
# IndexError: list index out of range
# INFO:Neuron:Compiling function _NeuronGraph$1037 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1037 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpeag9u58b/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpeag9u58b/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_52/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_52/aten_slice_1/StridedSlice:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpeag9u58b/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpeag9u58b/graph_def.neff --io-config {"inputs": {"0:0": [[33, 11], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_52/aten_add/add:0", "StochasticDurationPredictor_10/ConvFlow_52/aten_slice_1/StridedSlice:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1038 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1038 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpxzuq81x3/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpxzuq81x3/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_52/aten_add_3/add:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpxzuq81x3/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpxzuq81x3/graph_def.neff --io-config {"inputs": {"0:0": [[33, 1], "float32"], "1:0": [[33, 1], "float32"], "2:0": [[33, 1], "float32"], "3:0": [[33, 1], "float32"], "4:0": [[33, 1], "float32"], "5:0": [[33, 1], "float32"], "6:0": [[33, 1], "float32"], "7:0": [[33], "float32"]}, "outputs": ["StochasticDurationPredictor_10/ConvFlow_52/aten_add_3/add:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1039 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1039 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpqn5qo6sl/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpqn5qo6sl/graph_def.neff --io-config {"inputs": {"0:0": [[1, 1, 33], "float32"], "1:0": [[1, 1, 33], "float32"], "2:0": [[1, 1, 33], "float32"]}, "outputs": ["aten_ceil/Ceil:0", "aten_sum/Sum:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpqn5qo6sl/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpqn5qo6sl/graph_def.neff --io-config {"inputs": {"0:0": [[1, 1, 33], "float32"], "1:0": [[1, 1, 33], "float32"], "2:0": [[1, 1, 33], "float32"]}, "outputs": ["aten_ceil/Ceil:0", "aten_sum/Sum:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1040 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1040 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpro5hqbq1/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpro5hqbq1/graph_def.neff --io-config {"inputs": {"tensor.1:0": [[1], "float32"], "1:0": [[1, 1, 33], "float32"], "2:0": [[1, 1, 33], "float32"], "3:0": [[1, 192, 33], "float32"]}, "outputs": ["aten_to_1/Cast:0", "aten_mul_1/mul:0", "aten_transpose_2/transpose:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpro5hqbq1/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpro5hqbq1/graph_def.neff --io-config {"inputs": {"tensor.1:0": [[1], "float32"], "1:0": [[1, 1, 33], "float32"], "2:0": [[1, 1, 33], "float32"], "3:0": [[1, 192, 33], "float32"]}, "outputs": ["aten_to_1/Cast:0", "aten_mul_1/mul:0", "aten_transpose_2/transpose:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1041 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1041 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config {"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config {"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# WARNING:Neuron:The neuron-cc (neuron compiler) process aborted (SIG_ABORT).  This is likely due to an unexpected condition internally (a bug).  Please lodge an issue at 'https://github.com/aws/aws-neuron-sdk/issues'
# [WARNING] The neuron-cc (neuron compiler) process aborted (SIG_ABORT).  This is likely due to an unexpected condition internally (a bug).  Please lodge an issue at 'https://github.com/aws/aws-neuron-sdk/issues'
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1041; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1041; falling back to native python function call
# ERROR:Neuron:neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]}' --verbose 35
# [ERROR] neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp5ff6ws85/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp5ff6ws85/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 1, 50, 33], "float32"], "1:0": [[1, 192, 33], "float32"], "2:0": [[1, 192, 50], "float32"], "3:0": [[1, 192, 50], "float32"], "4:0": [[1, 1, 50], "float32"]}, "outputs": ["aten_transpose_1/transpose:0", "aten_add/add:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:1", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_split_with_sizes/split:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_80/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]}' --verbose 35
# INFO:Neuron:Compiling function _NeuronGraph$1042 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1042 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpj8knb3gp/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpj8knb3gp/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "1:0": [[1, 192, 50], "float32"], "2:0": [[1, 1, 50], "float32"]}, "outputs": ["ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_92/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_130/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpj8knb3gp/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpj8knb3gp/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "1:0": [[1, 192, 50], "float32"], "2:0": [[1, 1, 50], "float32"]}, "outputs": ["ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_92/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_130/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1043 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1043 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmprt7iph4r/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmprt7iph4r/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "1:0": [[1, 192, 50], "float32"], "2:0": [[1, 1, 50], "float32"]}, "outputs": ["ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_142/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_mul/mul:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/Conv1d_180/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_17/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# ...
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmpgr1bv9wq/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmpgr1bv9wq/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "1:0": [[1, 192, 50], "float32"], "2:0": [[1, 1, 50], "float32"]}, "outputs": ["ResidualCouplingBlock_147/ResidualCouplingLayer_23/WN_11/Conv1d_192/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/WN_11/Conv1d_230/aten__convolution/transpose_2:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/WN_11/aten_zeros_like/zeros_like:0"]} --verbose 35'
# INFO:Neuron:Compiling function _NeuronGraph$1057 with neuron-cc
# [INFO] Compiling function _NeuronGraph$1057 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]} --verbose 35'
# [INFO] Compiling with command line: '/home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config {"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]} --verbose 35'
# INFO:Neuron:Compile command returned: 1
# [INFO] Compile command returned: 1
# WARNING:Neuron:torch.neuron.trace failed on _NeuronGraph$1057; falling back to native python function call
# [WARNING] torch.neuron.trace failed on _NeuronGraph$1057; falling back to native python function call
# ERROR:Neuron:neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]}' --verbose 35
# [ERROR] neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]}' --verbose 35
# Traceback (most recent call last):
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/convert.py", line 392, in op_converter
#     item, inputs, compiler_workdir=sg_workdir, **kwargs)
#   File "/home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/decorators.py", line 229, in trace
#     'neuron-cc failed with the following command line call:\n{}'.format(command))
# subprocess.SubprocessError: neuron-cc failed with the following command line call:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/bin/neuron-cc compile /tmp/tmp3k70_423/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /tmp/tmp3k70_423/graph_def.neff --io-config '{"inputs": {"0:0": [[1, 192, 50], "float32"], "tensor.1:0": [[1, 384, 50], "float32"], "tensor.7:0": [[1, 384, 50], "float32"], "tensor.13:0": [[1, 384, 50], "float32"], "4:0": [[1, 192, 50], "float32"], "5:0": [[1, 1, 50], "float32"], "6:0": [[1, 96, 50], "float32"], "7:0": [[1, 96, 50], "float32"], "8:0": [[1, 192, 50], "float32"], "9:0": [[1, 192, 50], "float32"], "10:0": [[1, 192, 50], "float32"], "11:0": [[1, 1, 50, 33], "float32"]}, "outputs": ["Generator_164/aten_tanh/Tanh:0", "11:0", "5:0", "ResidualCouplingBlock_147/ResidualCouplingLayer_23/aten_cat/concat:0", "8:0", "9:0", "10:0"]}' --verbose 35
# INFO:Neuron:Number of arithmetic operators (post-compilation) before = 2066, compiled = 303, percent compiled = 14.67%
# [INFO] Number of arithmetic operators (post-compilation) before = 2066, compiled = 303, percent compiled = 14.67%
# INFO:Neuron:The neuron partitioner created 32 sub-graphs
# [INFO] The neuron partitioner created 32 sub-graphs
# INFO:Neuron:Neuron successfully compiled 20 sub-graphs, Total fused subgraphs = 32, Percent of model sub-graphs successfully compiled = 62.5%
# [INFO] Neuron successfully compiled 20 sub-graphs, Total fused subgraphs = 32, Percent of model sub-graphs successfully compiled = 62.5%
# INFO:Neuron:Compiled these operators (and operator counts) to Neuron:
# [INFO] Compiled these operators (and operator counts) to Neuron:
# INFO:Neuron: => aten::Int: 4
# [INFO]  => aten::Int: 4
# INFO:Neuron: => aten::ScalarImplicit: 2
# [INFO]  => aten::ScalarImplicit: 2
# INFO:Neuron: => aten::_convolution: 24
# [INFO]  => aten::_convolution: 24
# INFO:Neuron: => aten::_weight_norm: 24
# [INFO]  => aten::_weight_norm: 24
# INFO:Neuron: => aten::add: 27
# [INFO]  => aten::add: 27
# INFO:Neuron: => aten::arange: 2
# [INFO]  => aten::arange: 2
# INFO:Neuron: => aten::cat: 1
# [INFO]  => aten::cat: 1
# INFO:Neuron: => aten::ceil: 1
# [INFO]  => aten::ceil: 1
# INFO:Neuron: => aten::constant_pad_nd: 1
# [INFO]  => aten::constant_pad_nd: 1
# INFO:Neuron: => aten::cumsum: 1
# [INFO]  => aten::cumsum: 1
# INFO:Neuron: => aten::div: 3
# [INFO]  => aten::div: 3
# INFO:Neuron: => aten::dropout: 12
# [INFO]  => aten::dropout: 12
# INFO:Neuron: => aten::exp: 2
# [INFO]  => aten::exp: 2
# INFO:Neuron: => aten::flip: 1
# [INFO]  => aten::flip: 1
# INFO:Neuron: => aten::lt: 2
# [INFO]  => aten::lt: 2
# INFO:Neuron: => aten::matmul: 1
# [INFO]  => aten::matmul: 1
# INFO:Neuron: => aten::max: 1
# [INFO]  => aten::max: 1
# INFO:Neuron: => aten::mul: 53
# [INFO]  => aten::mul: 53
# INFO:Neuron: => aten::neg: 7
# [INFO]  => aten::neg: 7
# INFO:Neuron: => aten::pow: 3
# [INFO]  => aten::pow: 3
# INFO:Neuron: => aten::select: 21
# [INFO]  => aten::select: 21
# INFO:Neuron: => aten::size: 3
# [INFO]  => aten::size: 3
# INFO:Neuron: => aten::slice: 41
# [INFO]  => aten::slice: 41
# INFO:Neuron: => aten::softplus: 3
# [INFO]  => aten::softplus: 3
# INFO:Neuron: => aten::split_with_sizes: 1
# [INFO]  => aten::split_with_sizes: 1
# INFO:Neuron: => aten::sqrt: 3
# [INFO]  => aten::sqrt: 3
# INFO:Neuron: => aten::squeeze: 1
# [INFO]  => aten::squeeze: 1
# INFO:Neuron: => aten::sub: 29
# [INFO]  => aten::sub: 29
# INFO:Neuron: => aten::sum: 1
# [INFO]  => aten::sum: 1
# INFO:Neuron: => aten::to: 3
# [INFO]  => aten::to: 3
# INFO:Neuron: => aten::transpose: 3
# [INFO]  => aten::transpose: 3
# INFO:Neuron: => aten::unsqueeze: 8
# [INFO]  => aten::unsqueeze: 8
# INFO:Neuron: => aten::view: 2
# [INFO]  => aten::view: 2
# INFO:Neuron: => aten::zeros_like: 12
# [INFO]  => aten::zeros_like: 12
# INFO:Neuron:Not compiled operators (and operator counts) to Neuron:
# [INFO] Not compiled operators (and operator counts) to Neuron:
# INFO:Neuron: => aten::Int: 215 [supported]
# [INFO]  => aten::Int: 215 [supported]
# INFO:Neuron: => aten::ScalarImplicit: 1 [supported]
# [INFO]  => aten::ScalarImplicit: 1 [supported]
# INFO:Neuron: => aten::__and__: 3 [supported]
# [INFO]  => aten::__and__: 3 [supported]
# INFO:Neuron: => aten::_convolution: 163 [supported]
# [INFO]  => aten::_convolution: 163 [supported]
# INFO:Neuron: => aten::_weight_norm: 84 [supported]
# [INFO]  => aten::_weight_norm: 84 [supported]
# INFO:Neuron: => aten::add: 128 [supported]
# [INFO]  => aten::add: 128 [supported]
# INFO:Neuron: => aten::add_: 11 [supported]
# [INFO]  => aten::add_: 11 [supported]
# INFO:Neuron: => aten::arange: 1 [supported]
# [INFO]  => aten::arange: 1 [supported]
# INFO:Neuron: => aten::bitwise_not: 3 [supported]
# [INFO]  => aten::bitwise_not: 3 [supported]
# INFO:Neuron: => aten::cat: 6 [supported]
# [INFO]  => aten::cat: 6 [supported]
# INFO:Neuron: => aten::clamp_min: 1 [not supported]
# [INFO]  => aten::clamp_min: 1 [not supported]
# INFO:Neuron: => aten::constant_pad_nd: 57 [supported]
# [INFO]  => aten::constant_pad_nd: 57 [supported]
# INFO:Neuron: => aten::contiguous: 6 [supported]
# [INFO]  => aten::contiguous: 6 [supported]
# INFO:Neuron: => aten::copy_: 21 [supported]
# [INFO]  => aten::copy_: 21 [supported]
# INFO:Neuron: => aten::cumsum: 6 [supported]
# [INFO]  => aten::cumsum: 6 [supported]
# INFO:Neuron: => aten::detach: 1 [supported]
# [INFO]  => aten::detach: 1 [supported]
# INFO:Neuron: => aten::div: 25 [supported]
# [INFO]  => aten::div: 25 [supported]
# INFO:Neuron: => aten::dropout: 40 [supported]
# [INFO]  => aten::dropout: 40 [supported]
# INFO:Neuron: => aten::embedding: 1 [not supported]
# [INFO]  => aten::embedding: 1 [not supported]
# INFO:Neuron: => aten::eq: 6 [supported]
# [INFO]  => aten::eq: 6 [supported]
# INFO:Neuron: => aten::exp: 5 [supported]
# [INFO]  => aten::exp: 5 [supported]
# INFO:Neuron: => aten::expand: 18 [supported]
# [INFO]  => aten::expand: 18 [supported]
# INFO:Neuron: => aten::flip: 7 [supported]
# [INFO]  => aten::flip: 7 [supported]
# INFO:Neuron: => aten::gather: 21 [not supported]
# [INFO]  => aten::gather: 21 [not supported]
# INFO:Neuron: => aten::ge: 6 [supported]
# [INFO]  => aten::ge: 6 [supported]
# INFO:Neuron: => aten::gelu: 24 [supported]
# [INFO]  => aten::gelu: 24 [supported]
# INFO:Neuron: => aten::index: 15 [not supported]
# [INFO]  => aten::index: 15 [not supported]
# INFO:Neuron: => aten::index_put_: 6 [not supported]
# [INFO]  => aten::index_put_: 6 [not supported]
# INFO:Neuron: => aten::layer_norm: 36 [supported]
# [INFO]  => aten::layer_norm: 36 [supported]
# INFO:Neuron: => aten::le: 3 [supported]
# [INFO]  => aten::le: 3 [supported]
# INFO:Neuron: => aten::leaky_relu: 77 [supported]
# [INFO]  => aten::leaky_relu: 77 [supported]
# INFO:Neuron: => aten::lt: 1 [supported]
# [INFO]  => aten::lt: 1 [supported]
# INFO:Neuron: => aten::masked_fill: 6 [supported]
# [INFO]  => aten::masked_fill: 6 [supported]
# INFO:Neuron: => aten::matmul: 25 [supported]
# [INFO]  => aten::matmul: 25 [supported]
# INFO:Neuron: => aten::mul: 130 [supported]
# [INFO]  => aten::mul: 130 [supported]
# INFO:Neuron: => aten::neg: 4 [supported]
# [INFO]  => aten::neg: 4 [supported]
# INFO:Neuron: => aten::permute: 3 [supported]
# [INFO]  => aten::permute: 3 [supported]
# INFO:Neuron: => aten::pow: 6 [supported]
# [INFO]  => aten::pow: 6 [supported]
# INFO:Neuron: => aten::randn: 1 [not supported]
# [INFO]  => aten::randn: 1 [not supported]
# INFO:Neuron: => aten::randn_like: 1 [not supported]
# [INFO]  => aten::randn_like: 1 [not supported]
# INFO:Neuron: => aten::relu: 6 [supported]
# [INFO]  => aten::relu: 6 [supported]
# INFO:Neuron: => aten::reshape: 3 [supported]
# [INFO]  => aten::reshape: 3 [supported]
# INFO:Neuron: => aten::rsub: 6 [supported]
# [INFO]  => aten::rsub: 6 [supported]
# INFO:Neuron: => aten::select: 24 [supported]
# [INFO]  => aten::select: 24 [supported]
# INFO:Neuron: => aten::size: 75 [supported]
# [INFO]  => aten::size: 75 [supported]
# INFO:Neuron: => aten::slice: 141 [supported]
# [INFO]  => aten::slice: 141 [supported]
# INFO:Neuron: => aten::softmax: 12 [supported]
# [INFO]  => aten::softmax: 12 [supported]
# INFO:Neuron: => aten::split: 1 [supported]
# [INFO]  => aten::split: 1 [supported]
# INFO:Neuron: => aten::split_with_sizes: 7 [supported]
# [INFO]  => aten::split_with_sizes: 7 [supported]
# INFO:Neuron: => aten::squeeze: 1 [supported]
# [INFO]  => aten::squeeze: 1 [supported]
# INFO:Neuron: => aten::sub: 67 [supported]
# [INFO]  => aten::sub: 67 [supported]
# INFO:Neuron: => aten::sum: 3 [supported]
# [INFO]  => aten::sum: 3 [supported]
# INFO:Neuron: => aten::tanh: 1 [supported]
# [INFO]  => aten::tanh: 1 [supported]
# INFO:Neuron: => aten::to: 27 [supported]
# [INFO]  => aten::to: 27 [supported]
# INFO:Neuron: => aten::transpose: 111 [supported]
# [INFO]  => aten::transpose: 111 [supported]
# INFO:Neuron: => aten::unsqueeze: 23 [supported]
# [INFO]  => aten::unsqueeze: 23 [supported]
# INFO:Neuron: => aten::view: 66 [supported]
# [INFO]  => aten::view: 66 [supported]
# INFO:Neuron: => aten::zeros_like: 15 [supported]
# [INFO]  => aten::zeros_like: 15 [supported]
# WARNING:Neuron:torch.neuron.trace was unable to compile > 50% of the operators in the compiled model!
# [WARNING] torch.neuron.trace was unable to compile > 50% of the operators in the compiled model!
# WARNING:Neuron:Please review the torch.neuron.analyze_model output and if you believe you are seeing a failure
# [WARNING] Please review the torch.neuron.analyze_model output and if you believe you are seeing a failure
# WARNING:Neuron:Lodge an issue on https://github.com/aws/aws-neuron-sdk/issues if you believe the model is not compiling as expected
# [WARNING] Lodge an issue on https://github.com/aws/aws-neuron-sdk/issues if you believe the model is not compiling as expected

# %%
# 트레이스된 모델 저장
torch.jit.save(traced_model, "traced_vits_model_neuron.pt")

# %% [markdown]
# ## 모델 추론

# %%
# Prepare input
# stn_tst = get_text("VITS is Awesome!", hps)
stn_tst = get_text("Melon is a great fruit in summer for everybody", hps)

x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
# Convert scalar value to tensor
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

# %%
# inference
traced_output = traced_model(x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale)
print("output shape:", traced_output[0].shape)

ipd.display(ipd.Audio(traced_output, rate=hps.data.sampling_rate, normalize=False))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## 모델 로딩후 추론 테스트

# %%
import torch
import torch_neuron
import commons
import utils
from text import text_to_sequence

hps = utils.get_hparams_from_file("./configs/ljs_base.json")

def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

def load_neuron_model(model_path):
    device = torch.device("cpu")  # 먼저 CPU에 로드
    model = torch.jit.load(model_path, map_location=device)
    return torch_neuron.DataParallel(model)


# Prepare input
stn_tst = get_text("VITS is Awesome!", hps)

x_tst = stn_tst.unsqueeze(0)
x_tst_lengths = torch.LongTensor([stn_tst.size(0)])
# Convert scalar value to tensor
noise_scale = torch.tensor(0.667)
noise_scale_w = torch.tensor(0.8)
length_scale = torch.tensor(1.0)

# %%
# 사용 예시
model_path = "traced_vits_model_neuron.pt"
loaded_neuron_model = load_neuron_model(model_path)

# %%
# inference
traced_output = loaded_neuron_model(x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale)
print("output shape:", traced_output[0].shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-b7f9bb64cece> in <module>
#       1 # inference
# ----> 2 traced_output = loaded_neuron_model(x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale)
#       3 print("output shape:", traced_output[0].shape)
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/data_parallel.py in forward(self, *inputs)
#     212             return self.module(*inputs)
#     213
# --> 214         inputs = scatter_inputs(inputs, self.device_ids, self.split_size, self.dim)
#     215         if not inputs:
#     216             inputs = ((),)
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/data_parallel.py in scatter_inputs(inputs, device_ids, split_size, dim)
#     293
#     294 def scatter_inputs(inputs, device_ids, split_size, dim=0):
# --> 295     inputs = scatter(inputs, device_ids, split_size, dim)
#     296     inputs = tuple(inputs)
#     297     return inputs
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/data_parallel.py in scatter(inputs, device_ids, split_size_, dim)
#     286
#     287     try:
# --> 288         res = scatter_map(inputs)
#     289     finally:
#     290         scatter_map = None
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/data_parallel.py in scatter_map(obj)
#     278             return [type(obj)(*args) for args in zip(*map(scatter_map, obj))]
#     279         if isinstance(obj, tuple) and len(obj) > 0:
# --> 280             return list(zip(*map(scatter_map, obj)))
#     281         if isinstance(obj, list) and len(obj) > 0:
#     282             return [list(i) for i in zip(*map(scatter_map, obj))]
#
# ~/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch_neuron/data_parallel.py in scatter_map(obj)
#     260         if isinstance(obj, torch.Tensor):
#     261             num_devices = len(device_ids)
# --> 262             num_batches = obj.shape[dim]
#     263             split_size,remainder = _get_split_size(split_size_, num_devices, dim, obj)
#     264
#
# IndexError: tuple index out of range

# %% [markdown]
# ## Neuron Analyzer

# %%
import torch
import torch_neuron
from torch_neuron import analyze_model

analyzer = analyze_model(wrapped_model, (x_tst, x_tst_lengths, noise_scale, noise_scale_w, length_scale))
# Out:
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:14: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:15: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   from ipykernel import kernelapp as app
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   app.launch_new_instance()
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%7880 : Float(1, 192, 100, strides=[19200, 1, 192], requires_grad=0, device=cpu) = aten::randn_like(%m_p, %7875, %7876, %7877, %7878, %7879) # /home/ubuntu/vits/models.py:547:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _module_class,
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# expected tensor shape torch.Size([1, 1, 24576]) doesn't match with actual tensor shape torch.Size([1, 1, 25600])!
#   _module_class,
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# expected tensor shape torch.Size([1, 1, 96, 33]) doesn't match with actual tensor shape torch.Size([1, 1, 100, 33])!
#   _module_class,
# /home/ubuntu/miniconda3/envs/vits-conda-py36/lib/python3.6/site-packages/torch/jit/_trace.py:985: TracerWarning: Output nr 3. of the traced function does not match the corresponding output of the Python function. Detailed error:
# expected tensor shape torch.Size([1, 1, 96]) doesn't match with actual tensor shape torch.Size([1, 1, 100])!
#   _module_class,
# INFO:Neuron:The following operations are currently supported in torch-neuron for this model:
# [INFO] The following operations are currently supported in torch-neuron for this model:
# INFO:Neuron:aten::ScalarImplicit
# [INFO] aten::ScalarImplicit
# INFO:Neuron:aten::sqrt
# [INFO] aten::sqrt
# INFO:Neuron:aten::to
# [INFO] aten::to
# INFO:Neuron:aten::matmul
# [INFO] aten::matmul
# INFO:Neuron:aten::sub
# [INFO] aten::sub
# INFO:Neuron:aten::exp
# [INFO] aten::exp
# INFO:Neuron:prim::Constant
# [INFO] prim::Constant
# INFO:Neuron:aten::_weight_norm
# [INFO] aten::_weight_norm
# INFO:Neuron:prim::NumToTensor
# [INFO] prim::NumToTensor
# INFO:Neuron:aten::ge
# [INFO] aten::ge
# INFO:Neuron:aten::slice
# [INFO] aten::slice
# INFO:Neuron:aten::lt
# [INFO] aten::lt
# INFO:Neuron:aten::eq
# [INFO] aten::eq
# INFO:Neuron:aten::copy_
# [INFO] aten::copy_
# INFO:Neuron:aten::split_with_sizes
# [INFO] aten::split_with_sizes
# INFO:Neuron:aten::pow
# [INFO] aten::pow
# INFO:Neuron:aten::size
# [INFO] aten::size
# INFO:Neuron:aten::constant_pad_nd
# [INFO] aten::constant_pad_nd
# INFO:Neuron:aten::gelu
# [INFO] aten::gelu
# INFO:Neuron:aten::__and__
# [INFO] aten::__and__
# INFO:Neuron:aten::view
# [INFO] aten::view
# INFO:Neuron:aten::squeeze
# [INFO] aten::squeeze
# INFO:Neuron:prim::TupleUnpack
# [INFO] prim::TupleUnpack
# INFO:Neuron:aten::detach
# [INFO] aten::detach
# INFO:Neuron:aten::sum
# [INFO] aten::sum
# INFO:Neuron:aten::transpose
# [INFO] aten::transpose
# INFO:Neuron:aten::arange
# [INFO] aten::arange
# INFO:Neuron:aten::bitwise_not
# [INFO] aten::bitwise_not
# INFO:Neuron:aten::leaky_relu
# [INFO] aten::leaky_relu
# INFO:Neuron:aten::tanh
# [INFO] aten::tanh
# INFO:Neuron:aten::mul
# [INFO] aten::mul
# INFO:Neuron:aten::expand
# [INFO] aten::expand
# INFO:Neuron:aten::layer_norm
# [INFO] aten::layer_norm
# INFO:Neuron:aten::le
# [INFO] aten::le
# INFO:Neuron:aten::Int
# [INFO] aten::Int
# INFO:Neuron:aten::softplus
# [INFO] aten::softplus
# INFO:Neuron:aten::add_
# [INFO] aten::add_
# INFO:Neuron:aten::flip
# [INFO] aten::flip
# INFO:Neuron:aten::add
# [INFO] aten::add
# INFO:Neuron:aten::masked_fill
# [INFO] aten::masked_fill
# INFO:Neuron:aten::rsub
# [INFO] aten::rsub
# INFO:Neuron:aten::div
# [INFO] aten::div
# INFO:Neuron:aten::cumsum
# [INFO] aten::cumsum
# INFO:Neuron:aten::softmax
# [INFO] aten::softmax
# INFO:Neuron:aten::dropout
# [INFO] aten::dropout
# INFO:Neuron:aten::permute
# [INFO] aten::permute
# INFO:Neuron:aten::select
# [INFO] aten::select
# INFO:Neuron:aten::contiguous
# [INFO] aten::contiguous
# INFO:Neuron:prim::ListConstruct
# [INFO] prim::ListConstruct
# INFO:Neuron:aten::relu
# [INFO] aten::relu
# INFO:Neuron:aten::zeros_like
# [INFO] aten::zeros_like
# INFO:Neuron:aten::reshape
# [INFO] aten::reshape
# INFO:Neuron:aten::max
# [INFO] aten::max
# INFO:Neuron:aten::_convolution
# [INFO] aten::_convolution
# INFO:Neuron:aten::split
# [INFO] aten::split
# INFO:Neuron:prim::ListUnpack
# [INFO] prim::ListUnpack
# INFO:Neuron:aten::neg
# [INFO] aten::neg
# INFO:Neuron:aten::cat
# [INFO] aten::cat
# INFO:Neuron:aten::unsqueeze
# [INFO] aten::unsqueeze
# INFO:Neuron:prim::TupleConstruct
# [INFO] prim::TupleConstruct
# INFO:Neuron:aten::ceil
# [INFO] aten::ceil
# INFO:Neuron:The following operations are currently not supported in torch-neuron for this model:
# [INFO] The following operations are currently not supported in torch-neuron for this model:
# INFO:Neuron:aten::clamp_min
# [INFO] aten::clamp_min
# INFO:Neuron:aten::embedding
# [INFO] aten::embedding
# INFO:Neuron:aten::gather
# [INFO] aten::gather
# INFO:Neuron:aten::index
# [INFO] aten::index
# INFO:Neuron:aten::index_put_
# [INFO] aten::index_put_
# INFO:Neuron:aten::randn
# [INFO] aten::randn
# INFO:Neuron:aten::randn_like
# [INFO] aten::randn_like
# INFO:Neuron:prim::CallFunction
# [INFO] prim::CallFunction
# INFO:Neuron:99.28% of all operations (including primitives) (8548 of 8610) are supported
# [INFO] 99.28% of all operations (including primitives) (8548 of 8610) are supported
# INFO:Neuron:97.77% of arithmetic operations (2020 of 2066) are supported
# [INFO] 97.77% of arithmetic operations (2020 of 2066) are supported
